# %% [markdown]
# # Code from Cleon-Wong [https://github.com/CleonWong/Can-You-Find-The-Tumour]
# # Figure out how to extract and rename .dcm files
#
# **Problem:**
#
# The .dcm files download from CBIS-DDSM are stored in a very nested folder structure that is difficult for a script to access. We need to move these files into a single folder and rename the files according to what images they are (either full mammogram scan, cropped image or mask image).

# %%
import os
import shutil
import pydicom
import pandas as pd
from pathlib import Path

import numpy as np
import random

# %%
top = Path("/datasets/mamografia/CBIS-DDSM_organized/images/train")   #test images full mammogram

# %% [markdown]
# ## Helper functions

# %%
def new_name_dcm(dcm_path):
    
    """
    This function takes the absolute path of a .dcm file
    and renames it according to the convention below:
    
    1. Full mammograms:
        - Mass-Training_P_00001_LEFT_CC_FULL.dcm
    2. Cropped image:
        - Mass-Training_P_00001_LEFT_CC_CROP_1.dcm
        - Mass-Training_P_00001_LEFT_CC_CROP_2.dcm
        - ...
    3. Mask image:
        - Mass-Training_P_00001_LEFT_CC_MASK_1.dcm
        - Mass-Training_P_00001_LEFT_CC_MASK_2.dcm
        - ...
    
    
    Parameters
    ----------
    dcm_path : {str}
        The relative (or absolute) path of the .dcm file
        to rename, including the .dcm filename.
        e.g. "source_folder/Mass-Training_P_00001_LEFT_CC/1-1.dcm"

    Returns
    -------
    new_name : {str}
        The new name that the .dcm file should have
        WITH the ".dcm" extention WITHOUT its relative
        (or absolute) path.
        e.g. "Mass-Training_P_00001_LEFT_CC_FULL.dcm"
    False : {boolean}
        False is returned if the new name of the .dcm
        file cannot be determined.
    """
    
    try:
        # Read dicom.
        ds = pydicom.dcmread(dcm_path)
    
    except Exception as ex:
        print(ex)
        return None
    
    else:
        # Get information.
        patient_id = ds.PatientID
        img_type = ds.SeriesDescription

        # === FULL ===
        if "full" in img_type:
            new_name = patient_id + "_FULL" + ".dcm"
            print(f"FULL --- {new_name}")
            return new_name

        # === CROP ===
        elif "crop" in img_type:

            # Double check if suffix is integer. 
            suffix = patient_id.split("_")[-1]

            if suffix.isdigit():
                new_patient_id = patient_id.split("_" + suffix)[0]
                new_name = new_patient_id + "_CROP" + "_" + suffix + ".dcm"
                print(f"CROP --- {new_name}")
                return new_name

            elif not suffix.isdigit():
                print(f"CROP ERROR, {patient_id}")
                return False

        # === MASK ===
        elif "mask" in img_type:

            # Double check if suffix is integer. 
            suffix = patient_id.split("_")[-1]

            if suffix.isdigit():
                new_patient_id = patient_id.split("_" + suffix)[0]
                new_name = new_patient_id + "_MASK" + "_" + suffix + ".dcm"
                print(f"MASK --- {new_name}")
                return new_name


            elif not suffix.isdigit():
                print(f"MASK ERROR, {patient_id}")
                return False

        # === img_type NOT RECOGNISED ===
        else:
            print(f"img_type CANNOT BE IDENTIFIED, {img_type}")
            return False

# %%
def move_dcm_up(dest_dir, source_dir, dcm_filename):

    """
    This function move a .dcm file from its given source
    directory into the given destination directory. It also
    handles conflicting filenames by adding "___a" to the
    end of a filename if the filename already exists in the
    destination directory.
    
    Parameters
    ----------
    dest_dir : {str}
        The relative (or absolute) path of the folder that
        the .dcm file needs to be moved to.
    source_dir : {str}
        The relative (or absolute) path where the .dcm file
        needs to be moved from, including the filename.
        e.g. "source_folder/Mass-Training_P_00001_LEFT_CC_FULL.dcm"
    dcm_filename : {str}
        The name of the .dcm file WITH the ".dcm" extension
        but WITHOUT its (relative or absolute) path.
        e.g. "Mass-Training_P_00001_LEFT_CC_FULL.dcm".
        
    Returns
    -------
    None
    """
    
    dest_dir_with_new_name = os.path.join(dest_dir, dcm_filename)

    # If the destination path does not exist yet...
    if not os.path.exists(dest_dir_with_new_name):
        shutil.move(source_dir, dest_dir)

    # If the destination path already exists...
    elif os.path.exists(dest_dir_with_new_name):
        # Add "_a" to the end of `new_name` generated above.
        new_name_2 = dcm_filename.strip(".dcm") + "___a.dcm"
        # This moves the file into the destination while giving the file its new name.
        shutil.move(source_dir, os.path.join(dest_dir, new_name_2))

# %%
def delete_empty_folders(top, error_dir):
    
    """
    This function recursively walks through a given directory
    (`top`) using depth-first search (bottom up) and deletes
    any directory that is empty (ignoring hidden files).
    If there are directories that are not empty (except hidden
    files), it will save the absolute directory in a Pandas
    dataframe and export it as a `not-empty-folders.csv` to
    `error_dir`.

    Parameters
    ----------
    top : {str}
        The directory to iterate through.
    error_dir : {str}
        The directory to save the `not-empty-folders.csv` to.

    Returns
    -------
    None
    """
    
    curdir_list = []
    files_list = []
    
    for (curdir, dirs, files) in os.walk(top=top, topdown=False):
    
        if curdir != str(top):

            dirs.sort()
            files.sort()

            print(f"WE ARE AT: {curdir}")
            print("=" * 10)

            print("List dir:")

            directories_list = [f for f in os.listdir(curdir) if not f.startswith('.')]
            print(directories_list)

            if len(directories_list) == 0:
                print("DELETE")
                shutil.rmtree(curdir, ignore_errors=True)

            elif len(directories_list) > 0:
                print("DON'T DELETE")
                curdir_list.append(curdir)
                files_list.append(directories_list)

            print()
            print("Moving one folder up...")
            print("-" * 40)
            print()

    if len(curdir_list) > 0:
        not_empty_df = pd.DataFrame(list(zip(curdir_list, files_list)),
                                    columns =["curdir", "files"])
        to_save_path = os.path.join(error_dir, "not-empty-folders.csv")
        not_empty_df.to_csv(to_save_path, index=False)

# %% [markdown]
# ## 1. Count how many .dcm files before executing

# %%
before = 0

# Count number of .dcm files in ../data/Mass/Test.
for rootdir, dirs, files in os.walk(top):
    for f in files:
        if f.endswith(".dcm"):
            before += 1

print(f"BEFORE --> Number of .dcm files: {before}")
# Out:
# BEFORE --> Number of .dcm files: 3867

# %% [markdown]
# ## 2. Execute

# %%
# Rename and move .dcm files.
for (curdir, dirs, files) in os.walk(top=top, topdown=False):

    dirs.sort()
    files.sort()

    print(f"WE ARE AT: {curdir}")
    print("=" * 10)
    
    for f in files:
        
        # === Step 1: Rename .dcm file ===
        if f.endswith(".dcm"):
            
            old_name_path = os.path.join(curdir, f)
            new_name = new_name_dcm(dcm_path=old_name_path)
            
            if new_name:
                new_name_path = os.path.join(curdir, new_name)
                os.rename(old_name_path, new_name_path)
        
                # === Step 2: Move RENAMED .dcm file ===
                move_dcm_up(dest_dir=top, source_dir=new_name_path, dcm_filename=new_name)
    
    print()
    print("Moving one folder up...")
    print("-" * 40)
    print()
# Out:
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00419_LEFT_MLO/07-20-2016-DDSM-NA-77629/1.000000-full mammogram images-33580
# ==========
# FULL --- Mass-Training_P_00419_LEFT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00419_LEFT_MLO/07-20-2016-DDSM-NA-77629
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00419_LEFT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01185_RIGHT_MLO/07-20-2016-DDSM-NA-81896/1.000000-full mammogram images-90284
# ==========
# FULL --- Mass-Training_P_01185_RIGHT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01185_RIGHT_MLO/07-20-2016-DDSM-NA-81896
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01185_RIGHT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01983_LEFT_MLO/07-20-2016-DDSM-NA-67431/1.000000-full mammogram images-43230
# ==========
# FULL --- Mass-Training_P_01983_LEFT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01983_LEFT_MLO/07-20-2016-DDSM-NA-67431
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01983_LEFT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00859_LEFT_MLO/07-20-2016-DDSM-NA-29802/1.000000-full mammogram images-08300
# ==========
# FULL --- Mass-Training_P_00859_LEFT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00859_LEFT_MLO/07-20-2016-DDSM-NA-29802
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00859_LEFT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00504_RIGHT_MLO/07-20-2016-DDSM-NA-93714/1.000000-full mammogram images-48420
# ==========
# FULL --- Mass-Training_P_00504_RIGHT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00504_RIGHT_MLO/07-20-2016-DDSM-NA-93714
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00504_RIGHT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00294_LEFT_CC/07-20-2016-DDSM-NA-66873/1.000000-full mammogram images-84158
# ==========
# FULL --- Mass-Training_P_00294_LEFT_CC_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00294_LEFT_CC/07-20-2016-DDSM-NA-66873
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00294_LEFT_CC
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01739_LEFT_CC/07-20-2016-DDSM-NA-92779/1.000000-full mammogram images-98092
# ==========
# FULL --- Mass-Training_P_01739_LEFT_CC_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01739_LEFT_CC/07-20-2016-DDSM-NA-92779
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01739_LEFT_CC
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00294_LEFT_MLO/07-20-2016-DDSM-NA-92718/1.000000-full mammogram images-11911
# ==========
# FULL --- Mass-Training_P_00294_LEFT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00294_LEFT_MLO/07-20-2016-DDSM-NA-92718
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00294_LEFT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01382_LEFT_MLO/07-20-2016-DDSM-NA-93921/1.000000-full mammogram images-05891
# ==========
# FULL --- Mass-Training_P_01382_LEFT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01382_LEFT_MLO/07-20-2016-DDSM-NA-93921
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01382_LEFT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00335_LEFT_MLO/07-20-2016-DDSM-NA-72433/1.000000-full mammogram images-01704
# ==========
# FULL --- Mass-Training_P_00335_LEFT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00335_LEFT_MLO/07-20-2016-DDSM-NA-72433
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00335_LEFT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00719_LEFT_MLO/07-20-2016-DDSM-NA-87988/1.000000-full mammogram images-28906
# ==========
# FULL --- Mass-Training_P_00719_LEFT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00719_LEFT_MLO/07-20-2016-DDSM-NA-87988
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00719_LEFT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00065_LEFT_MLO/07-20-2016-DDSM-NA-69793/1.000000-full mammogram images-73679
# ==========
# FULL --- Mass-Training_P_00065_LEFT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00065_LEFT_MLO/07-20-2016-DDSM-NA-69793
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00065_LEFT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01305_LEFT_MLO/07-20-2016-DDSM-NA-02892/1.000000-full mammogram images-79906
# ==========
# FULL --- Mass-Training_P_01305_LEFT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01305_LEFT_MLO/07-20-2016-DDSM-NA-02892
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01305_LEFT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01755_RIGHT_CC/07-20-2016-DDSM-NA-47363/1.000000-full mammogram images-50579
# ==========
# FULL --- Mass-Training_P_01755_RIGHT_CC_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01755_RIGHT_CC/07-20-2016-DDSM-NA-47363
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01755_RIGHT_CC
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00389_LEFT_MLO/07-20-2016-DDSM-NA-06769/1.000000-full mammogram images-13691
# ==========
# FULL --- Mass-Training_P_00389_LEFT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00389_LEFT_MLO/07-20-2016-DDSM-NA-06769
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00389_LEFT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01134_RIGHT_CC/07-20-2016-DDSM-NA-92625/1.000000-full mammogram images-75580
# ==========
# FULL --- Mass-Training_P_01134_RIGHT_CC_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01134_RIGHT_CC/07-20-2016-DDSM-NA-92625
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01134_RIGHT_CC
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01720_RIGHT_MLO/07-20-2016-DDSM-NA-87231/1.000000-full mammogram images-37976
# ==========
# FULL --- Mass-Training_P_01720_RIGHT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01720_RIGHT_MLO/07-20-2016-DDSM-NA-87231
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01720_RIGHT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00039_RIGHT_MLO/07-20-2016-DDSM-NA-34862/1.000000-full mammogram images-49660
# ==========
# FULL --- Mass-Training_P_00039_RIGHT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00039_RIGHT_MLO/07-20-2016-DDSM-NA-34862
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00039_RIGHT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01151_RIGHT_MLO/07-20-2016-DDSM-NA-95396/1.000000-full mammogram images-47852
# ==========
# FULL --- Mass-Training_P_01151_RIGHT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01151_RIGHT_MLO/07-20-2016-DDSM-NA-95396
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01151_RIGHT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00901_RIGHT_CC/07-20-2016-DDSM-NA-82134/1.000000-full mammogram images-54862
# ==========
# FULL --- Mass-Training_P_00901_RIGHT_CC_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00901_RIGHT_CC/07-20-2016-DDSM-NA-82134
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00901_RIGHT_CC
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00475_RIGHT_MLO/07-20-2016-DDSM-NA-83398/1.000000-full mammogram images-61117
# ==========
# FULL --- Mass-Training_P_00475_RIGHT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00475_RIGHT_MLO/07-20-2016-DDSM-NA-83398
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00475_RIGHT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00190_LEFT_MLO/07-20-2016-DDSM-NA-33299/1.000000-full mammogram images-63719
# ==========
# FULL --- Mass-Training_P_00190_LEFT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00190_LEFT_MLO/07-20-2016-DDSM-NA-33299
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00190_LEFT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00333_RIGHT_CC/07-20-2016-DDSM-NA-15934/1.000000-full mammogram images-50742
# ==========
# FULL --- Mass-Training_P_00333_RIGHT_CC_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00333_RIGHT_CC/07-20-2016-DDSM-NA-15934
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00333_RIGHT_CC
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00695_RIGHT_CC/07-20-2016-DDSM-NA-95122/1.000000-full mammogram images-79450
# ==========
# FULL --- Mass-Training_P_00695_RIGHT_CC_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00695_RIGHT_CC/07-20-2016-DDSM-NA-95122
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00695_RIGHT_CC
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01486_RIGHT_MLO/07-20-2016-DDSM-NA-23670/1.000000-full mammogram images-40814
# ==========
# FULL --- Mass-Training_P_01486_RIGHT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01486_RIGHT_MLO/07-20-2016-DDSM-NA-23670
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01486_RIGHT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01531_RIGHT_MLO/07-20-2016-DDSM-NA-08081/1.000000-full mammogram images-60148
# ==========
# FULL --- Mass-Training_P_01531_RIGHT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01531_RIGHT_MLO/07-20-2016-DDSM-NA-08081
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01531_RIGHT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00432_LEFT_MLO/07-20-2016-DDSM-NA-33534/1.000000-full mammogram images-29315
# ==========
# FULL --- Mass-Training_P_00432_LEFT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00432_LEFT_MLO/07-20-2016-DDSM-NA-33534
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00432_LEFT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00703_LEFT_CC/07-20-2016-DDSM-NA-43138/1.000000-full mammogram images-76552
# ==========
# FULL --- Mass-Training_P_00703_LEFT_CC_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00703_LEFT_CC/07-20-2016-DDSM-NA-43138
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00703_LEFT_CC
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01737_RIGHT_CC/07-20-2016-DDSM-NA-28858/1.000000-full mammogram images-69225
# ==========
# FULL --- Mass-Training_P_01737_RIGHT_CC_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01737_RIGHT_CC/07-20-2016-DDSM-NA-28858
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01737_RIGHT_CC
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01231_LEFT_CC/07-20-2016-DDSM-NA-70067/1.000000-full mammogram images-74079
# ==========
# FULL --- Mass-Training_P_01231_LEFT_CC_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01231_LEFT_CC/07-20-2016-DDSM-NA-70067
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01231_LEFT_CC
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00848_LEFT_CC/07-20-2016-DDSM-NA-92490/1.000000-full mammogram images-12163
# ==========
# FULL --- Mass-Training_P_00848_LEFT_CC_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00848_LEFT_CC/07-20-2016-DDSM-NA-92490
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00848_LEFT_CC
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01725_RIGHT_CC/07-20-2016-DDSM-NA-68111/1.000000-full mammogram images-27765
# ==========
# FULL --- Mass-Training_P_01725_RIGHT_CC_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01725_RIGHT_CC/07-20-2016-DDSM-NA-68111
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01725_RIGHT_CC
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00776_RIGHT_CC/07-20-2016-DDSM-NA-68072/1.000000-full mammogram images-75862
# ==========
# FULL --- Mass-Training_P_00776_RIGHT_CC_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00776_RIGHT_CC/07-20-2016-DDSM-NA-68072
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00776_RIGHT_CC
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00794_LEFT_MLO/07-20-2016-DDSM-NA-42797/1.000000-full mammogram images-25898
# ==========
# FULL --- Mass-Training_P_00794_LEFT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00794_LEFT_MLO/07-20-2016-DDSM-NA-42797
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00794_LEFT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00149_LEFT_CC/07-20-2016-DDSM-NA-41615/1.000000-full mammogram images-34348
# ==========
# FULL --- Mass-Training_P_00149_LEFT_CC_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00149_LEFT_CC/07-20-2016-DDSM-NA-41615
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00149_LEFT_CC
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01325_RIGHT_MLO/07-20-2016-DDSM-NA-39889/1.000000-full mammogram images-14952
# ==========
# FULL --- Mass-Training_P_01325_RIGHT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01325_RIGHT_MLO/07-20-2016-DDSM-NA-39889
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01325_RIGHT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00802_LEFT_CC/07-20-2016-DDSM-NA-69171/1.000000-full mammogram images-66344
# ==========
# FULL --- Mass-Training_P_00802_LEFT_CC_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00802_LEFT_CC/07-20-2016-DDSM-NA-69171
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00802_LEFT_CC
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01070_LEFT_MLO/07-20-2016-DDSM-NA-39401/1.000000-full mammogram images-94833
# ==========
# FULL --- Mass-Training_P_01070_LEFT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01070_LEFT_MLO/07-20-2016-DDSM-NA-39401
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01070_LEFT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01281_RIGHT_MLO/07-20-2016-DDSM-NA-18462/1.000000-full mammogram images-77048
# ==========
# FULL --- Mass-Training_P_01281_RIGHT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01281_RIGHT_MLO/07-20-2016-DDSM-NA-18462
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01281_RIGHT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00999_LEFT_MLO/07-20-2016-DDSM-NA-33653/1.000000-full mammogram images-76477
# ==========
# FULL --- Mass-Training_P_00999_LEFT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00999_LEFT_MLO/07-20-2016-DDSM-NA-33653
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00999_LEFT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00549_LEFT_CC/07-20-2016-DDSM-NA-15623/1.000000-full mammogram images-11837
# ==========
# FULL --- Mass-Training_P_00549_LEFT_CC_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00549_LEFT_CC/07-20-2016-DDSM-NA-15623
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00549_LEFT_CC
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01394_LEFT_MLO/07-20-2016-DDSM-NA-10253/1.000000-full mammogram images-20050
# ==========
# FULL --- Mass-Training_P_01394_LEFT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01394_LEFT_MLO/07-20-2016-DDSM-NA-10253
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01394_LEFT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01241_RIGHT_CC/07-20-2016-DDSM-NA-75794/1.000000-full mammogram images-92627
# ==========
# FULL --- Mass-Training_P_01241_RIGHT_CC_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01241_RIGHT_CC/07-20-2016-DDSM-NA-75794
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01241_RIGHT_CC
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01768_LEFT_CC/07-20-2016-DDSM-NA-77842/1.000000-full mammogram images-01658
# ==========
# FULL --- Mass-Training_P_01768_LEFT_CC_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01768_LEFT_CC/07-20-2016-DDSM-NA-77842
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01768_LEFT_CC
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01371_RIGHT_CC/07-20-2016-DDSM-NA-17458/1.000000-full mammogram images-71460
# ==========
# FULL --- Mass-Training_P_01371_RIGHT_CC_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01371_RIGHT_CC/07-20-2016-DDSM-NA-17458
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01371_RIGHT_CC
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00577_RIGHT_MLO/07-20-2016-DDSM-NA-39658/1.000000-full mammogram images-36804
# ==========
# FULL --- Mass-Training_P_00577_RIGHT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00577_RIGHT_MLO/07-20-2016-DDSM-NA-39658
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00577_RIGHT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01048_RIGHT_CC/07-20-2016-DDSM-NA-28795/1.000000-full mammogram images-63188
# ==========
# FULL --- Mass-Training_P_01048_RIGHT_CC_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01048_RIGHT_CC/07-20-2016-DDSM-NA-28795
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01048_RIGHT_CC
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01608_RIGHT_MLO/07-20-2016-DDSM-NA-18254/1.000000-full mammogram images-49786
# ==========
# FULL --- Mass-Training_P_01608_RIGHT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01608_RIGHT_MLO/07-20-2016-DDSM-NA-18254
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01608_RIGHT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00884_LEFT_MLO/07-20-2016-DDSM-NA-00669/1.000000-full mammogram images-16147
# ==========
# FULL --- Mass-Training_P_00884_LEFT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00884_LEFT_MLO/07-20-2016-DDSM-NA-00669
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_00884_LEFT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01890_LEFT_MLO/07-20-2016-DDSM-NA-37683/1.000000-full mammogram images-15047
# ==========
# FULL --- Mass-Training_P_01890_LEFT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01890_LEFT_MLO/07-20-2016-DDSM-NA-37683
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01890_LEFT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01946_RIGHT_MLO/07-20-2016-DDSM-NA-73156/1.000000-full mammogram images-64301
# ==========
# FULL --- Mass-Training_P_01946_RIGHT_MLO_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01946_RIGHT_MLO/07-20-2016-DDSM-NA-73156
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01946_RIGHT_MLO
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01103_RIGHT_CC/07-20-2016-DDSM-NA-47396/1.000000-full mammogram images-06440
# ==========
# FULL --- Mass-Training_P_01103_RIGHT_CC_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01103_RIGHT_CC/07-20-2016-DDSM-NA-47396
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01103_RIGHT_CC
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01216_RIGHT_CC/07-20-2016-DDSM-NA-27504/1.000000-full mammogram images-16794
# ==========
# FULL --- Mass-Training_P_01216_RIGHT_CC_FULL.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_full_mammogram_images/manifest-Egq0PU078220738724328010106/CBIS-DDSM/Mass-Training_P_01216_RIGHT_CC/07-20-2016-DDSM-NA-27504
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# ...
# ==========
# MASK --- Mass-Training_P_00046_RIGHT_MLO_MASK_1.dcm
# CROP --- Mass-Training_P_00046_RIGHT_MLO_CROP_1.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_00046_RIGHT_MLO_1/07-21-2016-DDSM-NA-36723
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_00046_RIGHT_MLO_1
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_00660_LEFT_CC_1/07-21-2016-DDSM-NA-80896/1.000000-ROI mask images-63680
# ==========
# MASK --- Mass-Training_P_00660_LEFT_CC_MASK_1.dcm
# CROP --- Mass-Training_P_00660_LEFT_CC_CROP_1.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_00660_LEFT_CC_1/07-21-2016-DDSM-NA-80896
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_00660_LEFT_CC_1
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_00844_RIGHT_MLO_1/07-21-2016-DDSM-NA-86316/1.000000-ROI mask images-23995
# ==========
# MASK --- Mass-Training_P_00844_RIGHT_MLO_MASK_1.dcm
# CROP --- Mass-Training_P_00844_RIGHT_MLO_CROP_1.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_00844_RIGHT_MLO_1/07-21-2016-DDSM-NA-86316
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_00844_RIGHT_MLO_1
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_01710_LEFT_CC_1/07-21-2016-DDSM-NA-18310/1.000000-ROI mask images-04380
# ==========
# MASK --- Mass-Training_P_01710_LEFT_CC_MASK_1.dcm
# CROP --- Mass-Training_P_01710_LEFT_CC_CROP_1.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_01710_LEFT_CC_1/07-21-2016-DDSM-NA-18310
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_01710_LEFT_CC_1
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_01124_RIGHT_CC_1/07-21-2016-DDSM-NA-62163/1.000000-ROI mask images-02152
# ==========
# MASK --- Mass-Training_P_01124_RIGHT_CC_MASK_1.dcm
# CROP --- Mass-Training_P_01124_RIGHT_CC_CROP_1.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_01124_RIGHT_CC_1/07-21-2016-DDSM-NA-62163
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_01124_RIGHT_CC_1
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_01632_RIGHT_MLO_1/07-21-2016-DDSM-NA-47914/1.000000-ROI mask images-84399
# ==========
# CROP --- Mass-Training_P_01632_RIGHT_MLO_CROP_1.dcm
# MASK --- Mass-Training_P_01632_RIGHT_MLO_MASK_1.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_01632_RIGHT_MLO_1/07-21-2016-DDSM-NA-47914
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_01632_RIGHT_MLO_1
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_01649_LEFT_CC_1/07-21-2016-DDSM-NA-07382/1.000000-ROI mask images-76813
# ==========
# CROP --- Mass-Training_P_01649_LEFT_CC_CROP_1.dcm
# MASK --- Mass-Training_P_01649_LEFT_CC_MASK_1.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_01649_LEFT_CC_1/07-21-2016-DDSM-NA-07382
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_01649_LEFT_CC_1
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_00604_LEFT_CC_1/07-21-2016-DDSM-NA-95464/1.000000-ROI mask images-61337
# ==========
# CROP --- Mass-Training_P_00604_LEFT_CC_CROP_1.dcm
# MASK --- Mass-Training_P_00604_LEFT_CC_MASK_1.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_00604_LEFT_CC_1/07-21-2016-DDSM-NA-95464
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_00604_LEFT_CC_1
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_01241_RIGHT_CC_1/07-21-2016-DDSM-NA-87043/1.000000-ROI mask images-28486
# ==========
# MASK --- Mass-Training_P_01241_RIGHT_CC_MASK_1.dcm
# CROP --- Mass-Training_P_01241_RIGHT_CC_CROP_1.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_01241_RIGHT_CC_1/07-21-2016-DDSM-NA-87043
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_01241_RIGHT_CC_1
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_00661_LEFT_MLO_1/07-21-2016-DDSM-NA-95922/1.000000-ROI mask images-58626
# ==========
# MASK --- Mass-Training_P_00661_LEFT_MLO_MASK_1.dcm
# CROP --- Mass-Training_P_00661_LEFT_MLO_CROP_1.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_00661_LEFT_MLO_1/07-21-2016-DDSM-NA-95922
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_00661_LEFT_MLO_1
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_00963_LEFT_MLO_1/07-21-2016-DDSM-NA-64064/1.000000-ROI mask images-52098
# ==========
# CROP --- Mass-Training_P_00963_LEFT_MLO_CROP_1.dcm
# MASK --- Mass-Training_P_00963_LEFT_MLO_MASK_1.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_00963_LEFT_MLO_1/07-21-2016-DDSM-NA-64064
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_00963_LEFT_MLO_1
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_01675_RIGHT_MLO_1/07-21-2016-DDSM-NA-43927/1.000000-ROI mask images-69225
# ==========
# CROP --- Mass-Training_P_01675_RIGHT_MLO_CROP_1.dcm
# MASK --- Mass-Training_P_01675_RIGHT_MLO_MASK_1.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_01675_RIGHT_MLO_1/07-21-2016-DDSM-NA-43927
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_01675_RIGHT_MLO_1
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_00903_LEFT_MLO_1/07-21-2016-DDSM-NA-34488/1.000000-ROI mask images-89415
# ==========
# CROP --- Mass-Training_P_00903_LEFT_MLO_CROP_1.dcm
# MASK --- Mass-Training_P_00903_LEFT_MLO_MASK_1.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_00903_LEFT_MLO_1/07-21-2016-DDSM-NA-34488
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_00903_LEFT_MLO_1
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_00294_LEFT_MLO_1/07-20-2016-DDSM-NA-31600/1.000000-cropped images-55989
# ==========
# CROP --- Mass-Training_P_00294_LEFT_MLO_CROP_1.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_00294_LEFT_MLO_1/07-20-2016-DDSM-NA-31600
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_00294_LEFT_MLO_1/07-21-2016-DDSM-NA-19063/1.000000-ROI mask images-51997
# ==========
# MASK --- Mass-Training_P_00294_LEFT_MLO_MASK_1.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_00294_LEFT_MLO_1/07-21-2016-DDSM-NA-19063
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_00294_LEFT_MLO_1
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_01149_RIGHT_MLO_1/07-21-2016-DDSM-NA-64426/1.000000-ROI mask images-87054
# ==========
# CROP --- Mass-Training_P_01149_RIGHT_MLO_CROP_1.dcm
# MASK --- Mass-Training_P_01149_RIGHT_MLO_MASK_1.dcm
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_01149_RIGHT_MLO_1/07-21-2016-DDSM-NA-64426
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM/Mass-Training_P_01149_RIGHT_MLO_1
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328/CBIS-DDSM
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images/manifest-LyDgOQGl3853937313152078328
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train/mass-training_roi-mask_and_crpped_images
# ==========
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: /datasets/mamografia/CBIS-DDSM_organized/images/train
# ==========
#
# Moving one folder up...
# ----------------------------------------

# %%
# Delete empty folders.
delete_empty_folders(top=top, error_dir=top)
# Out:
# WE ARE AT: ../dataaa/Mass-Training_P_00039_RIGHT_MLO_1/07-21-2016-DDSM-82715/1.000000-ROI mask images-05753
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00039_RIGHT_MLO_1/07-21-2016-DDSM-82715
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00039_RIGHT_MLO_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00004_LEFT_MLO_1/07-21-2016-DDSM-78769/1.000000-ROI mask images-10515
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00004_LEFT_MLO_1/07-21-2016-DDSM-78769
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00004_LEFT_MLO_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00051_LEFT_MLO_1/07-21-2016-DDSM-14815/1.000000-ROI mask images-93758
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00051_LEFT_MLO_1/07-21-2016-DDSM-14815
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00051_LEFT_MLO_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00009_RIGHT_CC/07-20-2016-DDSM-71955/1.000000-full mammogram images-15839
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00009_RIGHT_CC/07-20-2016-DDSM-71955
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00009_RIGHT_CC
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00065_LEFT_CC_1/07-21-2016-DDSM-65664/1.000000-ROI mask images-64462
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00065_LEFT_CC_1/07-21-2016-DDSM-65664
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00065_LEFT_CC_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00059_LEFT_CC/07-20-2016-DDSM-65702/1.000000-full mammogram images-23379
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00059_LEFT_CC/07-20-2016-DDSM-65702
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00059_LEFT_CC
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00044_RIGHT_MLO_2/07-21-2016-DDSM-98278/1.000000-ROI mask images-14207
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00044_RIGHT_MLO_2/07-21-2016-DDSM-98278
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00044_RIGHT_MLO_2
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00004_LEFT_CC/07-20-2016-DDSM-95697/1.000000-full mammogram images-46540
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00004_LEFT_CC/07-20-2016-DDSM-95697
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00004_LEFT_CC
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00027_RIGHT_CC_1/07-21-2016-DDSM-97400/1.000000-ROI mask images-65434
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00027_RIGHT_CC_1/07-21-2016-DDSM-97400
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00027_RIGHT_CC_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00015_LEFT_MLO_1/07-21-2016-DDSM-46937/1.000000-ROI mask images-78003
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00015_LEFT_MLO_1/07-21-2016-DDSM-46937
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00015_LEFT_MLO_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00004_LEFT_MLO/07-20-2016-DDSM-20939/1.000000-full mammogram images-00162
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00004_LEFT_MLO/07-20-2016-DDSM-20939
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00004_LEFT_MLO
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00059_LEFT_MLO_1/07-21-2016-DDSM-63603/1.000000-ROI mask images-80695
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00059_LEFT_MLO_1/07-21-2016-DDSM-63603
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00059_LEFT_MLO_1/07-20-2016-DDSM-17686/1.000000-cropped images-94902
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00059_LEFT_MLO_1/07-20-2016-DDSM-17686
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00059_LEFT_MLO_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00009_RIGHT_CC_1/07-21-2016-DDSM-66714/1.000000-ROI mask images-42192
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00009_RIGHT_CC_1/07-21-2016-DDSM-66714
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00009_RIGHT_CC_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00044_RIGHT_CC_3/07-21-2016-DDSM-14174/1.000000-ROI mask images-14592
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00044_RIGHT_CC_3/07-21-2016-DDSM-14174
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00044_RIGHT_CC_3
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00044_RIGHT_CC_4/07-21-2016-DDSM-00793/1.000000-ROI mask images-80968
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00044_RIGHT_CC_4/07-21-2016-DDSM-00793
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00044_RIGHT_CC_4
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00021_LEFT_CC_1/07-21-2016-DDSM-55420/1.000000-ROI mask images-00748
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00021_LEFT_CC_1/07-21-2016-DDSM-55420
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00021_LEFT_CC_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00026_LEFT_MLO/07-20-2016-DDSM-78886/1.000000-full mammogram images-57441
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00026_LEFT_MLO/07-20-2016-DDSM-78886
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00026_LEFT_MLO
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00045_LEFT_MLO_1/07-21-2016-DDSM-07348/1.000000-ROI mask images-23178
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00045_LEFT_MLO_1/07-21-2016-DDSM-07348
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00045_LEFT_MLO_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00051_LEFT_MLO/07-20-2016-DDSM-35388/1.000000-full mammogram images-04692
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00051_LEFT_MLO/07-20-2016-DDSM-35388
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00051_LEFT_MLO
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00057_RIGHT_CC/07-20-2016-DDSM-98685/1.000000-full mammogram images-74367
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00057_RIGHT_CC/07-20-2016-DDSM-98685
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00057_RIGHT_CC
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00044_RIGHT_CC_2/07-21-2016-DDSM-33313/1.000000-ROI mask images-60878
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00044_RIGHT_CC_2/07-21-2016-DDSM-33313
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00044_RIGHT_CC_2
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00041_LEFT_CC/07-20-2016-DDSM-97976/1.000000-full mammogram images-75992
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00041_LEFT_CC/07-20-2016-DDSM-97976
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00041_LEFT_CC
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00051_LEFT_CC/07-20-2016-DDSM-93090/1.000000-full mammogram images-62296
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00051_LEFT_CC/07-20-2016-DDSM-93090
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00051_LEFT_CC
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00001_LEFT_MLO_1/07-21-2016-DDSM-82526/1.000000-ROI mask images-86053
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00001_LEFT_MLO_1/07-21-2016-DDSM-82526
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00001_LEFT_MLO_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00065_LEFT_MLO/07-20-2016-DDSM-69793/1.000000-full mammogram images-73679
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00065_LEFT_MLO/07-20-2016-DDSM-69793
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00065_LEFT_MLO
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00068_RIGHT_CC/07-20-2016-DDSM-10759/1.000000-full mammogram images-16361
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00068_RIGHT_CC/07-20-2016-DDSM-10759
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00068_RIGHT_CC
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00018_RIGHT_CC_1/07-21-2016-DDSM-92063/1.000000-ROI mask images-81067
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00018_RIGHT_CC_1/07-21-2016-DDSM-92063
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00018_RIGHT_CC_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00021_RIGHT_CC/07-20-2016-DDSM-44750/1.000000-full mammogram images-07231
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00021_RIGHT_CC/07-20-2016-DDSM-44750
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00021_RIGHT_CC
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00023_RIGHT_MLO/07-20-2016-DDSM-28127/1.000000-full mammogram images-57214
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00023_RIGHT_MLO/07-20-2016-DDSM-28127
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00023_RIGHT_MLO
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00021_LEFT_MLO/07-20-2016-DDSM-23498/1.000000-full mammogram images-07923
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00021_LEFT_MLO/07-20-2016-DDSM-23498
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00021_LEFT_MLO
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00023_RIGHT_MLO_1/07-21-2016-DDSM-90295/1.000000-ROI mask images-44365
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00023_RIGHT_MLO_1/07-21-2016-DDSM-90295
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00023_RIGHT_MLO_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00026_LEFT_CC_1/07-21-2016-DDSM-50220/1.000000-ROI mask images-85541
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00026_LEFT_CC_1/07-21-2016-DDSM-50220
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00026_LEFT_CC_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00034_RIGHT_CC_1/07-21-2016-DDSM-86295/1.000000-ROI mask images-95197
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00034_RIGHT_CC_1/07-21-2016-DDSM-86295
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00034_RIGHT_CC_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00065_LEFT_CC/07-20-2016-DDSM-07979/1.000000-full mammogram images-43457
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00065_LEFT_CC/07-20-2016-DDSM-07979
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00065_LEFT_CC
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00061_RIGHT_CC_1/07-21-2016-DDSM-24250/1.000000-ROI mask images-66040
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00061_RIGHT_CC_1/07-21-2016-DDSM-24250
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00061_RIGHT_CC_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00061_RIGHT_MLO_1/07-21-2016-DDSM-82733/1.000000-ROI mask images-82381
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00061_RIGHT_MLO_1/07-21-2016-DDSM-82733
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00061_RIGHT_MLO_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00021_LEFT_CC/07-20-2016-DDSM-08921/1.000000-full mammogram images-27573
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00021_LEFT_CC/07-20-2016-DDSM-08921
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00021_LEFT_CC
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00004_RIGHT_MLO_1/07-21-2016-DDSM-83774/1.000000-ROI mask images-84846
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00004_RIGHT_MLO_1/07-21-2016-DDSM-83774
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00004_RIGHT_MLO_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00018_RIGHT_CC/07-20-2016-DDSM-18937/1.000000-full mammogram images-64601
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00018_RIGHT_CC/07-20-2016-DDSM-18937
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00018_RIGHT_CC
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00054_RIGHT_MLO/07-20-2016-DDSM-02184/1.000000-full mammogram images-62855
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00054_RIGHT_MLO/07-20-2016-DDSM-02184
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00054_RIGHT_MLO
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00046_RIGHT_MLO_1/07-21-2016-DDSM-36723/1.000000-ROI mask images-84709
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00046_RIGHT_MLO_1/07-21-2016-DDSM-36723
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00046_RIGHT_MLO_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00051_LEFT_CC_1/07-21-2016-DDSM-82535/1.000000-ROI mask images-08042
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00051_LEFT_CC_1/07-21-2016-DDSM-82535
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00051_LEFT_CC_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00015_LEFT_MLO/07-20-2016-DDSM-66724/1.000000-full mammogram images-63688
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00015_LEFT_MLO/07-20-2016-DDSM-66724
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00015_LEFT_MLO
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00061_RIGHT_MLO/07-20-2016-DDSM-14653/1.000000-full mammogram images-64653
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00061_RIGHT_MLO/07-20-2016-DDSM-14653
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00061_RIGHT_MLO
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00045_LEFT_CC_1/07-21-2016-DDSM-17635/1.000000-ROI mask images-64260
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00045_LEFT_CC_1/07-21-2016-DDSM-17635
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00045_LEFT_CC_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00018_RIGHT_MLO_1/07-21-2016-DDSM-95813/1.000000-ROI mask images-78596
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00018_RIGHT_MLO_1/07-21-2016-DDSM-95813
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00018_RIGHT_MLO_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00068_RIGHT_MLO_1/07-21-2016-DDSM-78706/1.000000-ROI mask images-97187
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00068_RIGHT_MLO_1/07-21-2016-DDSM-78706
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00068_RIGHT_MLO_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00039_RIGHT_CC_1/07-21-2016-DDSM-03714/1.000000-ROI mask images-72286
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00039_RIGHT_CC_1/07-21-2016-DDSM-03714
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00039_RIGHT_CC_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00027_RIGHT_CC/07-20-2016-DDSM-59553/1.000000-full mammogram images-95081
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00027_RIGHT_CC/07-20-2016-DDSM-59553
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00027_RIGHT_CC
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00004_RIGHT_MLO/07-20-2016-DDSM-24486/1.000000-full mammogram images-89890
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00004_RIGHT_MLO/07-20-2016-DDSM-24486
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00004_RIGHT_MLO
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00001_LEFT_CC_1/07-21-2016-DDSM-39106/1.000000-ROI mask images-99650
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00001_LEFT_CC_1/07-21-2016-DDSM-39106
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00001_LEFT_CC_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00041_LEFT_MLO/07-20-2016-DDSM-86875/1.000000-full mammogram images-41852
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00041_LEFT_MLO/07-20-2016-DDSM-86875
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00041_LEFT_MLO
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00009_RIGHT_MLO/07-20-2016-DDSM-85525/1.000000-full mammogram images-55201
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00009_RIGHT_MLO/07-20-2016-DDSM-85525
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00009_RIGHT_MLO
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00064_RIGHT_MLO_1/07-21-2016-DDSM-91991/1.000000-ROI mask images-45186
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00064_RIGHT_MLO_1/07-21-2016-DDSM-91991
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00064_RIGHT_MLO_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00046_RIGHT_MLO/07-20-2016-DDSM-88724/1.000000-full mammogram images-27479
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00046_RIGHT_MLO/07-20-2016-DDSM-88724
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00046_RIGHT_MLO
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00021_RIGHT_MLO_1/07-21-2016-DDSM-69339/1.000000-ROI mask images-17382
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00021_RIGHT_MLO_1/07-21-2016-DDSM-69339
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00021_RIGHT_MLO_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00004_LEFT_CC_1/07-21-2016-DDSM-30167/1.000000-ROI mask images-50375
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00004_LEFT_CC_1/07-21-2016-DDSM-30167
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00004_LEFT_CC_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00023_RIGHT_CC/07-20-2016-DDSM-19545/1.000000-full mammogram images-79091
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00023_RIGHT_CC/07-20-2016-DDSM-19545
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00023_RIGHT_CC
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00059_LEFT_MLO/07-20-2016-DDSM-95280/1.000000-full mammogram images-33323
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00059_LEFT_MLO/07-20-2016-DDSM-95280
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00059_LEFT_MLO
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00034_RIGHT_MLO/07-20-2016-DDSM-61638/1.000000-full mammogram images-97637
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00034_RIGHT_MLO/07-20-2016-DDSM-61638
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00034_RIGHT_MLO
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00026_LEFT_MLO_1/07-21-2016-DDSM-49569/1.000000-ROI mask images-94528
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00026_LEFT_MLO_1/07-21-2016-DDSM-49569
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00026_LEFT_MLO_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00023_RIGHT_CC_1/07-21-2016-DDSM-46282/1.000000-ROI mask images-20091
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00023_RIGHT_CC_1/07-21-2016-DDSM-46282
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00023_RIGHT_CC_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00018_RIGHT_MLO/07-20-2016-DDSM-09956/1.000000-full mammogram images-65391
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00018_RIGHT_MLO/07-20-2016-DDSM-09956
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00018_RIGHT_MLO
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00057_RIGHT_MLO/07-20-2016-DDSM-16745/1.000000-full mammogram images-42220
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00057_RIGHT_MLO/07-20-2016-DDSM-16745
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00057_RIGHT_MLO
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00044_RIGHT_MLO_1/07-21-2016-DDSM-76443/1.000000-ROI mask images-80862
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00044_RIGHT_MLO_1/07-21-2016-DDSM-76443
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00044_RIGHT_MLO_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00061_RIGHT_CC/07-20-2016-DDSM-56874/1.000000-full mammogram images-09919
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00061_RIGHT_CC/07-20-2016-DDSM-56874
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00061_RIGHT_CC
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00039_RIGHT_MLO/07-20-2016-DDSM-34862/1.000000-full mammogram images-49660
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00039_RIGHT_MLO/07-20-2016-DDSM-34862
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00039_RIGHT_MLO
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00034_RIGHT_MLO_1/07-21-2016-DDSM-45234/1.000000-ROI mask images-90712
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00034_RIGHT_MLO_1/07-21-2016-DDSM-45234
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00034_RIGHT_MLO_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00034_RIGHT_CC/07-20-2016-DDSM-32405/1.000000-full mammogram images-96906
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00034_RIGHT_CC/07-20-2016-DDSM-32405
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00034_RIGHT_CC
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00059_LEFT_CC_1/07-20-2016-DDSM-17695/1.000000-cropped images-02767
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00059_LEFT_CC_1/07-20-2016-DDSM-17695
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00059_LEFT_CC_1/07-21-2016-DDSM-38707/1.000000-ROI mask images-82600
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00059_LEFT_CC_1/07-21-2016-DDSM-38707
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00059_LEFT_CC_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00058_RIGHT_CC_1/07-21-2016-DDSM-70341/1.000000-ROI mask images-97513
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00058_RIGHT_CC_1/07-21-2016-DDSM-70341
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00058_RIGHT_CC_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00054_RIGHT_MLO_1/07-21-2016-DDSM-11471/1.000000-ROI mask images-85130
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00054_RIGHT_MLO_1/07-21-2016-DDSM-11471
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00054_RIGHT_MLO_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00044_RIGHT_CC_1/07-21-2016-DDSM-75344/1.000000-ROI mask images-25492
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00044_RIGHT_CC_1/07-21-2016-DDSM-75344
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00044_RIGHT_CC_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00041_LEFT_MLO_1/07-21-2016-DDSM-59632/1.000000-ROI mask images-90890
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00041_LEFT_MLO_1/07-21-2016-DDSM-59632
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00041_LEFT_MLO_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00064_RIGHT_MLO/07-20-2016-DDSM-89837/1.000000-full mammogram images-67605
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00064_RIGHT_MLO/07-20-2016-DDSM-89837
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00064_RIGHT_MLO
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00045_LEFT_MLO/07-20-2016-DDSM-53399/1.000000-full mammogram images-10341
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00045_LEFT_MLO/07-20-2016-DDSM-53399
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00045_LEFT_MLO
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00044_RIGHT_CC/07-20-2016-DDSM-79148/1.000000-full mammogram images-44331
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00044_RIGHT_CC/07-20-2016-DDSM-79148
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00044_RIGHT_CC
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00021_RIGHT_CC_1/07-21-2016-DDSM-26945/1.000000-ROI mask images-01991
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00021_RIGHT_CC_1/07-21-2016-DDSM-26945
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00021_RIGHT_CC_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00027_RIGHT_MLO_1/07-21-2016-DDSM-01785/1.000000-ROI mask images-83932
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00027_RIGHT_MLO_1/07-21-2016-DDSM-01785
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00027_RIGHT_MLO_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00057_RIGHT_MLO_1/07-21-2016-DDSM-58435/1.000000-ROI mask images-30373
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00057_RIGHT_MLO_1/07-21-2016-DDSM-58435
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00057_RIGHT_MLO_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00001_LEFT_MLO/07-20-2016-DDSM-90988/1.000000-full mammogram images-80834
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00001_LEFT_MLO/07-20-2016-DDSM-90988
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00001_LEFT_MLO
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00009_RIGHT_MLO_1/07-21-2016-DDSM-75455/1.000000-ROI mask images-19951
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00009_RIGHT_MLO_1/07-21-2016-DDSM-75455
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00009_RIGHT_MLO_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00068_RIGHT_CC_1/07-21-2016-DDSM-82707/1.000000-ROI mask images-31039
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00068_RIGHT_CC_1/07-21-2016-DDSM-82707
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00068_RIGHT_CC_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00026_LEFT_CC/07-20-2016-DDSM-97290/1.000000-full mammogram images-56297
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00026_LEFT_CC/07-20-2016-DDSM-97290
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00026_LEFT_CC
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00021_RIGHT_MLO/07-20-2016-DDSM-48943/1.000000-full mammogram images-17746
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00021_RIGHT_MLO/07-20-2016-DDSM-48943
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00021_RIGHT_MLO
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00039_RIGHT_CC/07-20-2016-DDSM-89888/1.000000-full mammogram images-69392
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00039_RIGHT_CC/07-20-2016-DDSM-89888
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00039_RIGHT_CC
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00001_LEFT_CC/07-20-2016-DDSM-74994/1.000000-full mammogram images-24515
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00001_LEFT_CC/07-20-2016-DDSM-74994
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00001_LEFT_CC
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00027_RIGHT_MLO/07-20-2016-DDSM-62597/1.000000-full mammogram images-05447
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00027_RIGHT_MLO/07-20-2016-DDSM-62597
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00027_RIGHT_MLO
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00068_RIGHT_MLO/07-20-2016-DDSM-04042/1.000000-full mammogram images-05604
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00068_RIGHT_MLO/07-20-2016-DDSM-04042
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00068_RIGHT_MLO
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00065_LEFT_MLO_1/07-21-2016-DDSM-45548/1.000000-ROI mask images-23885
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00065_LEFT_MLO_1/07-21-2016-DDSM-45548
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00065_LEFT_MLO_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00057_RIGHT_CC_1/07-21-2016-DDSM-75865/1.000000-ROI mask images-46688
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00057_RIGHT_CC_1/07-21-2016-DDSM-75865
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00057_RIGHT_CC_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00021_LEFT_MLO_1/07-21-2016-DDSM-98647/1.000000-ROI mask images-16905
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00021_LEFT_MLO_1/07-21-2016-DDSM-98647
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00021_LEFT_MLO_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00044_RIGHT_MLO/07-20-2016-DDSM-02892/1.000000-full mammogram images-63588
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00044_RIGHT_MLO/07-20-2016-DDSM-02892
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00044_RIGHT_MLO
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00058_RIGHT_CC/07-20-2016-DDSM-64915/1.000000-full mammogram images-19148
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00058_RIGHT_CC/07-20-2016-DDSM-64915
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00058_RIGHT_CC
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00045_LEFT_CC/07-20-2016-DDSM-23834/1.000000-full mammogram images-05742
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00045_LEFT_CC/07-20-2016-DDSM-23834
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00045_LEFT_CC
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00055_LEFT_CC_1/07-21-2016-DDSM-88382/1.000000-ROI mask images-35484
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00055_LEFT_CC_1/07-21-2016-DDSM-88382
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00055_LEFT_CC_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00055_LEFT_CC/07-20-2016-DDSM-27880/1.000000-full mammogram images-15856
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00055_LEFT_CC/07-20-2016-DDSM-27880
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00055_LEFT_CC
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00041_LEFT_CC_1/07-21-2016-DDSM-29032/1.000000-ROI mask images-34962
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00041_LEFT_CC_1/07-21-2016-DDSM-29032
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------
#
# WE ARE AT: ../dataaa/Mass-Training_P_00041_LEFT_CC_1
# ==========
# List dir:
# []
# DELETE
#
# Moving one folder up...
# ----------------------------------------

# %% [markdown]
# ## 3. Count how many .dcm files after executing

# %%
after = 0

# Count number of .dcm files in ../data/Mass/Test.
for rootdir, dirs, files in os.walk(top):
    for f in files:
        if f.endswith(".dcm"):
            after += 1

print(f"AFTER --> Number of .dcm files: {after}")
# Out:
# AFTER --> Number of .dcm files: 3867

# %% [markdown]
# ## Settle extracting of calcification test .dcm

# %%
top = "../data/raw_data/Calc/Test"

# %%
before = 0
for rootdir, dirs, files in os.walk(top):
    for f in files:
        if f.endswith(".dcm"):
            before += 1

print(before)
# Out:
# 936

# %%
top = "../data/preprocessed/Classification/all_classification"
extension = ".png"

mass = []
calc = []

for (curdir, dirs, files) in os.walk(top=top, topdown=False):

    dirs.sort()
    files.sort()

    for f in files:

        if f.endswith(extension):
            
            if "mass" in f.lower():
                mass.append(f)
            elif "calc" in f.lower():
                calc.append(f)

# %%
split = 0.2
mass_test_count = round(split * len(mass))
calc_test_count = round(split * len(calc))

mass_test = random.sample(mass, mass_test_count)
mass_train = [m for m in mass if m not in mass_test]

calc_test = random.sample(calc, calc_test_count)
calc_train = [c for c in calc if c not in calc_test]

test = mass_test + calc_test
train = mass_train + calc_train
# Out:
# 592 2369

# %%
test_df = pd.

# %%
# mass2 = [m.replace("Mass_", "") for m in mass]
# calc2 = [c.replace("Calc_", "") for c in calc]

# mass3 = [m.replace("_FULL___PRE.png", "") for m in mass2]
# calc3 = [c.replace("_FULL___PRE.png", "") for c in calc2]

# mass_set = set(mass3)
# calc_set = set(calc3)
# intersection = mass_set & calc_set

# to_remove_mass = [m for m in mass if any(inter in m for inter in intersection)]
# to_remove_calc = [c for c in calc if any(inter in c for inter in intersection)]

# to_remove = to_remove_mass + to_remove_calc

# for (curdir, dirs, files) in os.walk(top=top, topdown=False):

#     dirs.sort()
#     files.sort()
    
#     for f in files:
        
#         if f.endswith(".png") and f in to_remove:
#             os.remove(os.path.join(curdir, f))
