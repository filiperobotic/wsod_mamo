# %% [markdown]
# # Explore the .dcm files of BDIS-DDSM
#
# - [DICOM standard](https://dicom.innolitics.com/ciods/cr-image/general-series/00200060)

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from matplotlib.ticker import MultipleLocator
import pandas            as pd
import numpy             as np
import cv2
import pydicom
import os
import seaborn as sns
from skimage.segmentation import mark_boundaries

from pathlib             import Path

# %% [markdown]
# ---

# %%
# P00001_dcm = pydicom.dcmread("../data/raw_data/Mass/Train/Mass-Training_P_00001_LEFT_CC_FULL.dcm")
# P00001_mask_dcm = pydicom.dcmread("../data/raw_data/Mass/Train/Mass-Training_P_00001_LEFT_CC_MASK_1.dcm")
# P00001_crop_dcm = pydicom.dcmread("../data/raw_data/Mass/Train/Mass-Training_P_00001_LEFT_CC_CROP_1.dcm")

# P00444_dcm = pydicom.dcmread("/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Mass/Train_extracted/Mass-Training_P_00444_LEFT_CC_FULL.dcm")
# P00444_mask_dcm = pydicom.dcmread("/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Mass/Train_extracted/Mass-Training_P_00444_LEFT_CC_MASK_1.dcm")

# P00051_dcm = pydicom.dcmread("/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Mass/Train_extracted/Mass-Training_P_00051_LEFT_MLO_FULL.dcm")
# P00051_mask_dcm = pydicom.dcmread("/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Mass/Train_extracted/Mass-Training_P_00051_LEFT_MLO_MASK_1.dcm")

# P00001_arr = P00001_dcm.pixel_array
# P00001_mask_arr = P00001_mask_dcm.pixel_array
# P00001_crop_arr = P00001_crop_dcm.pixel_array

# P00444_arr = P00444_dcm.pixel_array
# P00444_mask_arr = P00444_mask_dcm.pixel_array

# P00051_arr = P00051_dcm.pixel_array
# P00051_mask_arr = P00051_mask_dcm.pixel_array

# %%
P00001_dcm = pydicom.dcmread("/datasets/mamografia/CBIS-DDSM_organized/images/train/Mass-Training_P_00001_LEFT_CC_FULL.dcm")
P00001_mask_dcm = pydicom.dcmread("/datasets/mamografia/CBIS-DDSM_organized/images/train/Mass-Training_P_00001_LEFT_CC_MASK_1.dcm")
P00001_crop_dcm = pydicom.dcmread("/datasets/mamografia/CBIS-DDSM_organized/images/train/Mass-Training_P_00001_LEFT_CC_CROP_1.dcm")

P00444_dcm = pydicom.dcmread("/datasets/mamografia/CBIS-DDSM_organized/images/train/Mass-Training_P_00444_LEFT_CC_FULL.dcm")
P00444_mask_dcm = pydicom.dcmread("/datasets/mamografia/CBIS-DDSM_organized/images/train/Mass-Training_P_00444_LEFT_CC_MASK_1.dcm")

P00051_dcm = pydicom.dcmread("/datasets/mamografia/CBIS-DDSM_organized/images/train/Mass-Training_P_00051_LEFT_MLO_FULL.dcm")
P00051_mask_dcm = pydicom.dcmread("/datasets/mamografia/CBIS-DDSM_organized/images/train/Mass-Training_P_00051_LEFT_MLO_MASK_1.dcm")

P00001_arr = P00001_dcm.pixel_array
P00001_mask_arr = P00001_mask_dcm.pixel_array
P00001_crop_arr = P00001_crop_dcm.pixel_array

P00444_arr = P00444_dcm.pixel_array
P00444_mask_arr = P00444_mask_dcm.pixel_array

P00051_arr = P00051_dcm.pixel_array
P00051_mask_arr = P00051_mask_dcm.pixel_array

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))

ax[0].imshow(P00001_arr, cmap="gray")
ax[1].imshow(P00001_mask_arr, cmap="gray")
ax[2].imshow(P00001_crop_arr, cmap="gray")

# %%
# cv2.imwrite("../writeups/medium_article/Mass-Training_P_00051_LEFT_MLO_MASK_1.png", P00051_mask_arr)
# Out:
# True

# %%
test = np.ma.masked_where(P00001_mask_arr == 0, P00001_mask_arr)

# %%
test
# Out:
# masked_array(
#   data=[[--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         ...,
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --]],
#   mask=[[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]],
#   fill_value=999999,
#   dtype=uint8)

# %%
# P00001_img = cv2.imread("../writeups/medium_article/Mass-Training_P_00001_LEFT_CC_FULL.png", cv2.IMREAD_GRAYSCALE)
# P00001_mask = cv2.imread("../writeups/medium_article/Mass-Training_P_00001_LEFT_CC_MASK_1.png", cv2.IMREAD_GRAYSCALE)

# P00051_img = cv2.imread("../writeups/medium_article/Mass-Training_P_00051_LEFT_MLO_FULL.png", cv2.IMREAD_GRAYSCALE)
# P00051_mask = cv2.imread("../writeups/medium_article/Mass-Training_P_00051_LEFT_MLO_MASK_1.png", cv2.IMREAD_GRAYSCALE)

# P00444_img = cv2.imread("../writeups/medium_article/Mass-Training_P_00444_LEFT_CC_FULL.png", cv2.IMREAD_GRAYSCALE)
# P00444_mask = cv2.imread("../writeups/medium_article/Mass-Training_P_00444_LEFT_CC_MASK_1.png", cv2.IMREAD_GRAYSCALE)

# %%
fig, ax = plt.subplots(nrows=3, ncols=3, figsize=(10, 15))

ax[0][0].imshow(P00001_arr, cmap="gray")
ax[1][0].imshow(P00001_mask_arr, cmap="gray")

ax[0][1].imshow(P00051_arr, cmap="gray")
ax[1][1].imshow(P00051_mask_arr, cmap="gray")

ax[0][2].imshow(P00444_arr, cmap="gray")
ax[1][2].imshow(P00444_mask_arr, cmap="gray")

def truncate_colormap(cmap, minval=0.0, maxval=1.0, n=100):
    new_cmap = colors.LinearSegmentedColormap.from_list(
        'trunc({n},{a:.2f},{b:.2f})'.format(n=cmap.name, a=minval, b=maxval),
        cmap(np.linspace(minval, maxval, n)))
    return new_cmap

bwr_cmap = plt.get_cmap("bwr")
true_cmap = truncate_colormap(cmap=bwr_cmap, minval=0.5, maxval=1.0)
pred_cmap = truncate_colormap(cmap=bwr_cmap, minval=0.5, maxval=0)

P00001_mask_alpha = np.ma.masked_where(P00001_mask_arr == 0, P00001_mask_arr)
P00051_mask_alpha = np.ma.masked_where(P00051_mask_arr == 0, P00051_mask_arr)
P00444_mask_alpha = np.ma.masked_where(P00444_mask_arr == 0, P00444_mask_arr)

ax[2][0].imshow(P00001_arr, cmap="gray")
ax[2][0].imshow(P00001_mask_alpha, cmap="cool", alpha=0.4)
# ax[2][0].imshow(P00001_mask_arr, cmap=true_cmap, alpha=0.4)
# ax[2][0].imshow(P00001_mask_arr, cmap=pred_cmap, alpha=0.4)

ax[2][1].imshow(P00051_arr, cmap="gray")
ax[2][1].imshow(P00051_mask_alpha, cmap="cool", alpha=0.4)
# ax[2][1].imshow(P00051_mask_arr, cmap=true_cmap, alpha=0.7)

ax[2][2].imshow(P00444_arr, cmap="gray")
ax[2][2].imshow(P00444_mask_alpha, cmap="cool", alpha=0.4)
# ax[2][2].imshow(P00444_mask_arr, cmap=true_cmap, alpha=0.4)

for i, ax in enumerate(fig.axes):
    ax.xaxis.set_visible(False)
    ax.yaxis.set_visible(False)

plt.subplots_adjust(wspace=0.2, 
                    hspace=0.05)
plt.tight_layout
# plt.savefig("/Users/cleonwong/Google Drive/To-Share/mammogram_medium_article/Part1/show_mask.png", dpi=300, transparent=True)
# Out:
# <function matplotlib.pyplot.tight_layout>

# %% [markdown]
# ## We only look at Mass-Training (patient IDs `P_00001` and `P_00004`)
#
# - `P_00001` - malignant
# - `P_00004` - benign
#
# **Note:**
# - `cropped image file path` and `ROI mask file path` are wrong.

# %%
df = pd.read_csv("/datasets/mamografia/CBIS-DDSM_organized/csv-description/mass_case_description_train_set.csv")

# Rename columns
new_cols = [col.replace(" ", "_") for col in df.columns]
df.columns = new_cols

df = df.loc[df["patient_id"].isin(["P_01039"])]
# df = df.loc[df["abnormality id"] > 1]



df
# Out:
#     patient_id  breast_density left_or_right_breast image_view  \
# 710    P_01039               1                 LEFT         CC
# 711    P_01039               1                RIGHT         CC
# 712    P_01039               1                RIGHT         CC
# 713    P_01039               1                RIGHT         CC
# 714    P_01039               1                RIGHT         CC
# 715    P_01039               1                RIGHT         CC
# 716    P_01039               1                RIGHT        MLO
# 717    P_01039               1                RIGHT        MLO
# 718    P_01039               1                RIGHT        MLO
# 719    P_01039               1                RIGHT        MLO
# 720    P_01039               1                RIGHT        MLO
# 721    P_01039               1                RIGHT        MLO
#
#      abnormality_id abnormality_type mass_shape   mass_margins  assessment  \
# 710               1             mass       OVAL     SPICULATED           5
# 711               1             mass      ROUND  CIRCUMSCRIBED           2
# 712               2             mass      ROUND  CIRCUMSCRIBED           2
# 713               3             mass      ROUND  CIRCUMSCRIBED           2
# 714               4             mass      ROUND  CIRCUMSCRIBED           2
# 715               6             mass      ROUND  CIRCUMSCRIBED           2
# 716               1             mass      ROUND  CIRCUMSCRIBED           2
# 717               2             mass      ROUND  CIRCUMSCRIBED           2
# 718               3             mass      ROUND  CIRCUMSCRIBED           2
# 719               4             mass      ROUND  CIRCUMSCRIBED           2
# 720               5             mass      ROUND  CIRCUMSCRIBED           2
# 721               6             mass      ROUND  CIRCUMSCRIBED           2
#
#      pathology  subtlety                                    image_file_path  \
# 710  MALIGNANT         5  Mass-Training_P_01039_LEFT_CC/1.3.6.1.4.1.9590...
# 711     BENIGN         5  Mass-Training_P_01039_RIGHT_CC/1.3.6.1.4.1.959...
# 712     BENIGN         5  Mass-Training_P_01039_RIGHT_CC/1.3.6.1.4.1.959...
# 713     BENIGN         5  Mass-Training_P_01039_RIGHT_CC/1.3.6.1.4.1.959...
# 714     BENIGN         5  Mass-Training_P_01039_RIGHT_CC/1.3.6.1.4.1.959...
# 715     BENIGN         5  Mass-Training_P_01039_RIGHT_CC/1.3.6.1.4.1.959...
# 716     BENIGN         5  Mass-Training_P_01039_RIGHT_MLO/1.3.6.1.4.1.95...
# 717     BENIGN         5  Mass-Training_P_01039_RIGHT_MLO/1.3.6.1.4.1.95...
# 718     BENIGN         5  Mass-Training_P_01039_RIGHT_MLO/1.3.6.1.4.1.95...
# 719     BENIGN         5  Mass-Training_P_01039_RIGHT_MLO/1.3.6.1.4.1.95...
# 720     BENIGN         5  Mass-Training_P_01039_RIGHT_MLO/1.3.6.1.4.1.95...
# 721     BENIGN         5  Mass-Training_P_01039_RIGHT_MLO/1.3.6.1.4.1.95...
#
#                                cropped_image_file_path  \
# 710  Mass-Training_P_01039_LEFT_CC_1/1.3.6.1.4.1.95...
# 711  Mass-Training_P_01039_RIGHT_CC_1/1.3.6.1.4.1.9...
# 712  Mass-Training_P_01039_RIGHT_CC_2/1.3.6.1.4.1.9...
# 713  Mass-Training_P_01039_RIGHT_CC_3/1.3.6.1.4.1.9...
# 714  Mass-Training_P_01039_RIGHT_CC_4/1.3.6.1.4.1.9...
# 715  Mass-Training_P_01039_RIGHT_CC_6/1.3.6.1.4.1.9...
# 716  Mass-Training_P_01039_RIGHT_MLO_1/1.3.6.1.4.1....
# 717  Mass-Training_P_01039_RIGHT_MLO_2/1.3.6.1.4.1....
# 718  Mass-Training_P_01039_RIGHT_MLO_3/1.3.6.1.4.1....
# 719  Mass-Training_P_01039_RIGHT_MLO_4/1.3.6.1.4.1....
# 720  Mass-Training_P_01039_RIGHT_MLO_5/1.3.6.1.4.1....
# 721  Mass-Training_P_01039_RIGHT_MLO_6/1.3.6.1.4.1....
#
#                                     ROI_mask_file_path
# 710  Mass-Training_P_01039_LEFT_CC_1/1.3.6.1.4.1.95...
# 711  Mass-Training_P_01039_RIGHT_CC_1/1.3.6.1.4.1.9...
# 712  Mass-Training_P_01039_RIGHT_CC_2/1.3.6.1.4.1.9...
# 713  Mass-Training_P_01039_RIGHT_CC_3/1.3.6.1.4.1.9...
# 714  Mass-Training_P_01039_RIGHT_CC_4/1.3.6.1.4.1.9...
# 715  Mass-Training_P_01039_RIGHT_CC_6/1.3.6.1.4.1.9...
# 716  Mass-Training_P_01039_RIGHT_MLO_1/1.3.6.1.4.1....
# 717  Mass-Training_P_01039_RIGHT_MLO_2/1.3.6.1.4.1....
# 718  Mass-Training_P_01039_RIGHT_MLO_3/1.3.6.1.4.1....
# 719  Mass-Training_P_01039_RIGHT_MLO_4/1.3.6.1.4.1....
# 720  Mass-Training_P_01039_RIGHT_MLO_5/1.3.6.1.4.1....
# 721  Mass-Training_P_01039_RIGHT_MLO_6/1.3.6.1.4.1....

# %%
for row in df.itertuples():
    print(row.ROI_mask_file_path)
    print(row.Index)
# Out:
# Mass-Training_P_01039_LEFT_CC_1/1.3.6.1.4.1.9590.100.1.2.292558450512308837809065724252939248630/1.3.6.1.4.1.9590.100.1.2.97236402913553087828237413621604953031/000001.dcm
#
# 710
# Mass-Training_P_01039_RIGHT_CC_1/1.3.6.1.4.1.9590.100.1.2.421530921711010785707159781733866271332/1.3.6.1.4.1.9590.100.1.2.360439647211144226518435419482007218051/000001.dcm
#
# 711
# Mass-Training_P_01039_RIGHT_CC_2/1.3.6.1.4.1.9590.100.1.2.13461259111869003126188550540520260103/1.3.6.1.4.1.9590.100.1.2.242213439512956311504125385422758273508/000001.dcm
#
# 712
# Mass-Training_P_01039_RIGHT_CC_3/1.3.6.1.4.1.9590.100.1.2.54695642910971545115448134861663281818/1.3.6.1.4.1.9590.100.1.2.64550621111072178514325551380316303032/000001.dcm
#
# 713
# Mass-Training_P_01039_RIGHT_CC_4/1.3.6.1.4.1.9590.100.1.2.73674296213312965829114316040664594257/1.3.6.1.4.1.9590.100.1.2.200674905911357193327065189363002199745/000001.dcm
#
# 714
# Mass-Training_P_01039_RIGHT_CC_6/1.3.6.1.4.1.9590.100.1.2.176725358711627243526364901200553260425/1.3.6.1.4.1.9590.100.1.2.69517822412677123440257901063254163503/000001.dcm
#
# 715
# Mass-Training_P_01039_RIGHT_MLO_1/1.3.6.1.4.1.9590.100.1.2.285979026611026823018295208170072040783/1.3.6.1.4.1.9590.100.1.2.369196829611754461201236350933606892864/000001.dcm
#
# 716
# Mass-Training_P_01039_RIGHT_MLO_2/1.3.6.1.4.1.9590.100.1.2.379415781313155495320608851272675247698/1.3.6.1.4.1.9590.100.1.2.24413910212876553434565096140956898495/000001.dcm
#
# 717
# Mass-Training_P_01039_RIGHT_MLO_3/1.3.6.1.4.1.9590.100.1.2.407114074011909679923210914780495795296/1.3.6.1.4.1.9590.100.1.2.233857989611138227638038250413861035851/000001.dcm
#
# 718
# Mass-Training_P_01039_RIGHT_MLO_4/1.3.6.1.4.1.9590.100.1.2.28307226212369827215874282672135758078/1.3.6.1.4.1.9590.100.1.2.296004277912329464712408641582909806637/000001.dcm
#
# 719
# Mass-Training_P_01039_RIGHT_MLO_5/1.3.6.1.4.1.9590.100.1.2.362043372912626851206266702392129953665/1.3.6.1.4.1.9590.100.1.2.67204285013759616112542232592030592136/000001.dcm
#
# 720
# Mass-Training_P_01039_RIGHT_MLO_6/1.3.6.1.4.1.9590.100.1.2.209141083313118462221852530470969063294/1.3.6.1.4.1.9590.100.1.2.272221283212513893305897289540411522478/000001.dcm
#
# 721

# %%
df.isna().sum()
# Out:
# patient_id                 0
# breast_density             0
# left_or_right_breast       0
# image_view                 0
# abnormality_id             0
# abnormality_type           0
# mass_shape                 0
# mass_margins               0
# assessment                 0
# pathology                  0
# subtlety                   0
# image_file_path            0
# cropped_image_file_path    0
# ROI_mask_file_path         0
# dtype: int64

# %%
df.head()
# Out:
#     patient_id  breast_density left_or_right_breast image_view  \
# 710    P_01039               1                 LEFT         CC
# 711    P_01039               1                RIGHT         CC
# 712    P_01039               1                RIGHT         CC
# 713    P_01039               1                RIGHT         CC
# 714    P_01039               1                RIGHT         CC
#
#      abnormality_id abnormality_type mass_shape   mass_margins  assessment  \
# 710               1             mass       OVAL     SPICULATED           5
# 711               1             mass      ROUND  CIRCUMSCRIBED           2
# 712               2             mass      ROUND  CIRCUMSCRIBED           2
# 713               3             mass      ROUND  CIRCUMSCRIBED           2
# 714               4             mass      ROUND  CIRCUMSCRIBED           2
#
#      pathology  subtlety                                    image_file_path  \
# 710  MALIGNANT         5  Mass-Training_P_01039_LEFT_CC/1.3.6.1.4.1.9590...
# 711     BENIGN         5  Mass-Training_P_01039_RIGHT_CC/1.3.6.1.4.1.959...
# 712     BENIGN         5  Mass-Training_P_01039_RIGHT_CC/1.3.6.1.4.1.959...
# 713     BENIGN         5  Mass-Training_P_01039_RIGHT_CC/1.3.6.1.4.1.959...
# 714     BENIGN         5  Mass-Training_P_01039_RIGHT_CC/1.3.6.1.4.1.959...
#
#                                cropped_image_file_path  \
# 710  Mass-Training_P_01039_LEFT_CC_1/1.3.6.1.4.1.95...
# 711  Mass-Training_P_01039_RIGHT_CC_1/1.3.6.1.4.1.9...
# 712  Mass-Training_P_01039_RIGHT_CC_2/1.3.6.1.4.1.9...
# 713  Mass-Training_P_01039_RIGHT_CC_3/1.3.6.1.4.1.9...
# 714  Mass-Training_P_01039_RIGHT_CC_4/1.3.6.1.4.1.9...
#
#                                     ROI_mask_file_path
# 710  Mass-Training_P_01039_LEFT_CC_1/1.3.6.1.4.1.95...
# 711  Mass-Training_P_01039_RIGHT_CC_1/1.3.6.1.4.1.9...
# 712  Mass-Training_P_01039_RIGHT_CC_2/1.3.6.1.4.1.9...
# 713  Mass-Training_P_01039_RIGHT_CC_3/1.3.6.1.4.1.9...
# 714  Mass-Training_P_01039_RIGHT_CC_4/1.3.6.1.4.1.9...

# %%
# df2 = pd.read_csv("/Users/cleonwong/Desktop/Code/mammogram-cv/data/raw_data/csv-description/Mass-Training-Description-UPDATED.csv")

# %% [markdown]
# ---
# ## Explore mass

# %% [markdown]
# ### Combining .csv for calc

# %%
# # Calc
# # ----

# calc_train_df = pd.read_csv("../data/raw_data/csv-description/Calc-Training-Description.csv")
# calc_test_df = pd.read_csv("../data/raw_data/csv-description/Calc-Test-Description.csv")

# calc_all_df = pd.concat(objs=[calc_train_df, calc_test_df])

# # Remove spaces in columns name
# calc_all_df.columns = calc_all_df.columns.str.replace(' ','_')

# # Drop path columns
# calc_all_df.drop(columns=["image_file_path", "cropped_image_file_path", "ROI_mask_file_path"], inplace=True)

# # Create identifier column for calc
# calc_all_df.insert(loc=0, column="identifier", value=np.nan)
# calc_all_df["identifier"] = calc_all_df.apply(lambda x: "_".join([x["patient_id"], x["left_or_right_breast"], x["image_view"]]), axis=1)

# # Mass
# # ----
# mass_all_df = pd.read_csv("../data/csv/Mass_all.csv")

# print(calc_all_df.shape)
# print(mass_all_df.shape)
# Out:
# (1872, 12)
# (1696, 12)

# %%
# Mass
# ----
mass_all_df = pd.read_csv("/datasets/mamografia/CBIS-DDSM_organized/csv-description/mass_case_description_train_set.csv")
new_cols = [col.replace(" ", "_") for col in mass_all_df.columns]
mass_all_df.columns = new_cols
mass_all_df["identifier"] = mass_all_df.apply(lambda x: "_".join([x["patient_id"], x["left_or_right_breast"], x["image_view"]]), axis=1)
print(mass_all_df.shape)
# Out:
# (1318, 15)

# %%
# print(len(calc_all_df["identifier"].unique()))
print(len(mass_all_df["identifier"].unique()))
# Out:
# 1231

# %%
mass_set
# Out:
# {'P_00234_LEFT_CC',
#  'P_01565_RIGHT_MLO',
#  'P_00108_LEFT_MLO',
#  'P_00399_RIGHT_CC',
#  'P_00687_LEFT_MLO',
#  'P_00708_RIGHT_MLO',
#  'P_00420_RIGHT_CC',
#  'P_00997_LEFT_CC',
#  'P_01499_RIGHT_CC',
#  'P_00428_LEFT_CC',
#  'P_00080_RIGHT_MLO',
#  'P_01343_LEFT_MLO',
#  'P_00711_LEFT_CC',
#  'P_01433_LEFT_MLO',
#  'P_01516_RIGHT_MLO',
#  'P_01634_LEFT_MLO',
#  'P_00990_RIGHT_CC',
#  'P_01280_RIGHT_CC',
#  'P_01646_LEFT_MLO',
#  'P_01803_RIGHT_CC',
#  'P_01878_RIGHT_CC',
#  'P_00453_LEFT_MLO',
#  'P_01267_RIGHT_MLO',
#  'P_00560_RIGHT_MLO',
#  'P_01849_RIGHT_CC',
#  'P_00117_LEFT_MLO',
#  'P_01822_LEFT_MLO',
#  'P_00519_RIGHT_CC',
#  'P_01152_RIGHT_CC',
#  'P_00421_LEFT_MLO',
#  'P_00859_LEFT_CC',
#  'P_01786_LEFT_CC',
#  'P_01215_RIGHT_MLO',
#  'P_00798_RIGHT_CC',
#  'P_00604_LEFT_MLO',
#  'P_01680_LEFT_MLO',
#  'P_01620_RIGHT_MLO',
#  'P_00694_RIGHT_MLO',
#  'P_01572_RIGHT_CC',
#  'P_01753_RIGHT_CC',
#  'P_00797_RIGHT_MLO',
#  'P_01757_RIGHT_MLO',
#  'P_01268_RIGHT_CC',
#  'P_01120_LEFT_MLO',
#  'P_01675_RIGHT_CC',
#  'P_01082_RIGHT_MLO',
#  'P_01508_LEFT_MLO',
#  'P_01636_RIGHT_MLO',
#  'P_01644_LEFT_CC',
#  'P_01946_RIGHT_MLO',
#  'P_01179_LEFT_MLO',
#  'P_01567_LEFT_MLO',
#  'P_00710_RIGHT_CC',
#  'P_00896_LEFT_CC',
#  'P_01226_LEFT_MLO',
#  'P_01402_RIGHT_MLO',
#  'P_01878_RIGHT_MLO',
#  'P_00781_RIGHT_CC',
#  'P_00061_RIGHT_MLO',
#  'P_00572_RIGHT_MLO',
#  'P_01149_RIGHT_CC',
#  'P_00710_LEFT_MLO',
#  'P_01442_RIGHT_CC',
#  'P_00059_LEFT_MLO',
#  'P_00303_RIGHT_MLO',
#  'P_00734_RIGHT_MLO',
#  'P_01152_RIGHT_MLO',
#  'P_01302_RIGHT_MLO',
#  'P_00844_RIGHT_MLO',
#  'P_00853_RIGHT_CC',
#  'P_00361_RIGHT_MLO',
#  'P_01212_RIGHT_MLO',
#  'P_01486_RIGHT_CC',
#  'P_00518_LEFT_MLO',
#  'P_01557_RIGHT_MLO',
#  'P_01798_LEFT_CC',
#  'P_00221_RIGHT_MLO',
#  'P_00553_LEFT_CC',
#  'P_01668_LEFT_CC',
#  'P_01103_RIGHT_MLO',
#  'P_00120_LEFT_MLO',
#  'P_00963_LEFT_MLO',
#  'P_00913_LEFT_MLO',
#  'P_01737_RIGHT_CC',
#  'P_00415_RIGHT_CC',
#  'P_01093_LEFT_MLO',
#  'P_01225_RIGHT_MLO',
#  'P_01243_LEFT_MLO',
#  'P_00451_LEFT_CC',
#  'P_00146_RIGHT_MLO',
#  'P_00366_RIGHT_CC',
#  'P_00453_LEFT_CC',
#  'P_00554_LEFT_MLO',
#  'P_00695_RIGHT_CC',
#  'P_00723_LEFT_MLO',
#  'P_00264_LEFT_CC',
#  'P_00733_RIGHT_CC',
#  'P_01123_LEFT_MLO',
#  'P_01326_LEFT_CC',
#  'P_00698_RIGHT_MLO',
#  'P_00848_LEFT_MLO',
#  'P_00988_LEFT_CC',
#  'P_01356_LEFT_CC',
#  'P_01398_LEFT_MLO',
#  'P_01735_RIGHT_CC',
#  'P_00242_RIGHT_MLO',
#  'P_01374_RIGHT_MLO',
#  'P_01486_RIGHT_MLO',
#  'P_00575_RIGHT_MLO',
#  'P_00637_RIGHT_CC',
#  'P_00836_LEFT_CC',
#  'P_01297_LEFT_MLO',
#  'P_01248_LEFT_CC',
#  'P_01619_LEFT_CC',
#  'P_00815_LEFT_CC',
#  'P_01564_RIGHT_CC',
#  'P_01118_RIGHT_MLO',
#  'P_00475_RIGHT_MLO',
#  'P_01529_RIGHT_CC',
#  'P_01444_RIGHT_MLO',
#  'P_01158_RIGHT_MLO',
#  'P_01687_RIGHT_MLO',
#  'P_01000_RIGHT_CC',
#  'P_00577_RIGHT_MLO',
#  'P_00240_RIGHT_MLO',
#  'P_00553_LEFT_MLO',
#  'P_01343_LEFT_CC',
#  'P_00829_LEFT_CC',
#  'P_00869_LEFT_MLO',
#  'P_01270_RIGHT_MLO',
#  'P_00515_LEFT_CC',
#  'P_00333_RIGHT_MLO',
#  'P_00504_RIGHT_MLO',
#  'P_00573_RIGHT_MLO',
#  'P_00661_LEFT_MLO',
#  'P_00545_LEFT_MLO',
#  'P_00174_RIGHT_MLO',
#  'P_00823_RIGHT_CC',
#  'P_01560_RIGHT_MLO',
#  'P_01822_LEFT_CC',
#  'P_01591_LEFT_MLO',
#  'P_00816_RIGHT_MLO',
#  'P_01194_LEFT_MLO',
#  'P_01564_RIGHT_MLO',
#  'P_00080_RIGHT_CC',
#  'P_00229_LEFT_CC',
#  'P_01853_LEFT_CC',
#  'P_00902_LEFT_MLO',
#  'P_00330_LEFT_CC',
#  'P_00995_LEFT_CC',
#  'P_01271_RIGHT_MLO',
#  'P_00863_RIGHT_MLO',
#  'P_00044_RIGHT_CC',
#  'P_00451_LEFT_MLO',
#  'P_01302_RIGHT_CC',
#  'P_01755_RIGHT_CC',
#  'P_00119_LEFT_MLO',
#  'P_00487_RIGHT_CC',
#  'P_00386_LEFT_MLO',
#  'P_00569_RIGHT_MLO',
#  'P_00754_LEFT_MLO',
#  'P_01124_RIGHT_MLO',
#  'P_01216_RIGHT_MLO',
#  'P_01423_RIGHT_CC',
#  'P_00239_RIGHT_CC',
#  'P_00309_LEFT_CC',
#  'P_00847_LEFT_MLO',
#  'P_00889_LEFT_CC',
#  'P_02092_LEFT_CC',
#  'P_00690_LEFT_MLO',
#  'P_01362_LEFT_MLO',
#  'P_00004_RIGHT_MLO',
#  'P_00411_RIGHT_MLO',
#  'P_01185_RIGHT_MLO',
#  'P_01887_LEFT_MLO',
#  'P_00692_LEFT_MLO',
#  'P_01556_LEFT_CC',
#  'P_00169_RIGHT_MLO',
#  'P_00958_LEFT_CC',
#  'P_01181_LEFT_MLO',
#  'P_01799_LEFT_CC',
#  'P_00137_LEFT_MLO',
#  'P_01218_RIGHT_CC',
#  'P_00044_RIGHT_MLO',
#  'P_00027_RIGHT_MLO',
#  'P_00298_LEFT_MLO',
#  'P_00915_RIGHT_MLO',
#  'P_01532_LEFT_CC',
#  'P_01712_RIGHT_CC',
#  'P_00886_LEFT_MLO',
#  'P_01819_RIGHT_CC',
#  'P_01264_LEFT_MLO',
#  'P_00412_RIGHT_MLO',
#  'P_00119_LEFT_CC',
#  'P_01354_RIGHT_MLO',
#  'P_01248_LEFT_MLO',
#  'P_01788_RIGHT_MLO',
#  'P_00577_RIGHT_CC',
#  'P_01685_RIGHT_MLO',
#  'P_01848_RIGHT_MLO',
#  'P_00240_RIGHT_CC',
#  'P_00863_RIGHT_CC',
#  'P_00289_LEFT_MLO',
#  'P_01733_RIGHT_MLO',
#  'P_00435_RIGHT_MLO',
#  'P_00549_LEFT_MLO',
#  'P_01981_RIGHT_CC',
#  'P_01057_RIGHT_CC',
#  'P_00004_LEFT_CC',
#  'P_00079_RIGHT_MLO',
#  'P_00972_LEFT_CC',
#  'P_01088_LEFT_CC',
#  'P_00254_LEFT_CC',
#  'P_01632_LEFT_MLO',
#  'P_01426_RIGHT_MLO',
#  'P_01238_RIGHT_MLO',
#  'P_01737_RIGHT_MLO',
#  'P_00731_RIGHT_CC',
#  'P_00592_LEFT_MLO',
#  'P_00728_RIGHT_MLO',
#  'P_01712_LEFT_CC',
#  'P_01268_RIGHT_MLO',
#  'P_00354_LEFT_MLO',
#  'P_00754_LEFT_CC',
#  'P_01364_LEFT_MLO',
#  'P_00550_RIGHT_MLO',
#  'P_01632_LEFT_CC',
#  'P_01841_RIGHT_CC',
#  'P_00439_RIGHT_CC',
#  'P_01720_RIGHT_CC',
#  'P_00626_LEFT_CC',
#  'P_00026_LEFT_MLO',
#  'P_01710_LEFT_CC',
#  'P_01501_RIGHT_MLO',
#  'P_00539_RIGHT_CC',
#  'P_01237_RIGHT_MLO',
#  'P_00921_RIGHT_CC',
#  'P_01701_LEFT_MLO',
#  'P_00426_RIGHT_CC',
#  'P_00430_LEFT_CC',
#  'P_00401_LEFT_MLO',
#  'P_00540_LEFT_CC',
#  'P_01271_RIGHT_CC',
#  'P_01663_RIGHT_CC',
#  'P_01832_RIGHT_MLO',
#  'P_00137_LEFT_CC',
#  'P_00706_RIGHT_MLO',
#  'P_00859_LEFT_MLO',
#  'P_01649_LEFT_CC',
#  'P_00333_RIGHT_CC',
#  'P_00413_LEFT_MLO',
#  'P_00517_LEFT_CC',
#  'P_01175_RIGHT_MLO',
#  'P_00045_LEFT_CC',
#  'P_01138_RIGHT_CC',
#  'P_01686_RIGHT_CC',
#  'P_00802_LEFT_MLO',
#  'P_00715_RIGHT_CC',
#  'P_00889_LEFT_MLO',
#  'P_01270_LEFT_CC',
#  'P_01079_RIGHT_MLO',
#  'P_00829_LEFT_MLO',
#  'P_00984_RIGHT_CC',
#  'P_01232_RIGHT_CC',
#  'P_00711_LEFT_MLO',
#  'P_01798_LEFT_MLO',
#  'P_00848_LEFT_CC',
#  'P_00596_LEFT_CC',
#  'P_00287_RIGHT_MLO',
#  'P_01383_LEFT_CC',
#  'P_01776_RIGHT_CC',
#  'P_01866_RIGHT_CC',
#  'P_01438_LEFT_MLO',
#  'P_01412_LEFT_MLO',
#  'P_00528_LEFT_MLO',
#  'P_00911_LEFT_CC',
#  'P_00976_LEFT_CC',
#  'P_00903_LEFT_MLO',
#  'P_01120_LEFT_CC',
#  'P_01382_LEFT_CC',
#  'P_00779_LEFT_CC',
#  'P_01162_LEFT_CC',
#  'P_00319_LEFT_MLO',
#  'P_00408_RIGHT_MLO',
#  'P_00265_RIGHT_MLO',
#  'P_00444_LEFT_CC',
#  'P_00914_LEFT_MLO',
#  'P_01840_RIGHT_MLO',
#  'P_00224_LEFT_MLO',
#  'P_00068_RIGHT_CC',
#  'P_01018_RIGHT_MLO',
#  'P_01206_RIGHT_CC',
#  'P_01475_LEFT_CC',
#  'P_00732_LEFT_CC',
#  'P_01608_RIGHT_CC',
#  'P_00675_LEFT_CC',
#  'P_00666_RIGHT_CC',
#  'P_00021_LEFT_CC',
#  'P_00265_RIGHT_CC',
#  'P_00794_LEFT_MLO',
#  'P_00034_RIGHT_MLO',
#  'P_00753_RIGHT_MLO',
#  'P_01516_RIGHT_CC',
#  'P_01305_LEFT_CC',
#  'P_01543_RIGHT_CC',
#  'P_00386_LEFT_CC',
#  'P_00522_RIGHT_MLO',
#  'P_01864_LEFT_CC',
#  'P_01406_LEFT_MLO',
#  'P_01725_RIGHT_MLO',
#  'P_00009_RIGHT_CC',
#  'P_00831_RIGHT_MLO',
#  'P_00166_RIGHT_CC',
#  'P_01328_LEFT_MLO',
#  'P_00432_LEFT_MLO',
#  'P_00174_RIGHT_CC',
#  'P_00995_LEFT_MLO',
#  'P_01131_LEFT_CC',
#  'P_01694_RIGHT_MLO',
#  'P_01052_LEFT_CC',
#  'P_01164_RIGHT_MLO',
#  'P_01215_RIGHT_CC',
#  'P_00376_RIGHT_MLO',
#  'P_00644_LEFT_MLO',
#  'P_01481_RIGHT_MLO',
#  'P_00247_RIGHT_MLO',
#  'P_00092_LEFT_MLO',
#  'P_00931_LEFT_CC',
#  'P_00225_RIGHT_CC',
#  'P_01250_RIGHT_MLO',
#  'P_00095_LEFT_CC',
#  'P_00509_RIGHT_MLO',
#  'P_00660_LEFT_MLO',
#  'P_01070_LEFT_MLO',
#  'P_01324_LEFT_MLO',
#  'P_01474_RIGHT_MLO',
#  'P_00509_RIGHT_CC',
#  'P_00622_LEFT_CC',
#  'P_01484_RIGHT_MLO',
#  'P_01203_RIGHT_CC',
#  'P_00976_LEFT_MLO',
#  'P_01151_RIGHT_CC',
#  'P_01501_RIGHT_CC',
#  'P_01557_RIGHT_CC',
#  'P_01109_LEFT_MLO',
#  'P_00207_LEFT_MLO',
#  'P_00952_RIGHT_CC',
#  'P_00781_RIGHT_MLO',
#  'P_01179_LEFT_CC',
#  'P_01009_RIGHT_CC',
#  'P_00057_RIGHT_CC',
#  'P_01083_RIGHT_MLO',
#  'P_01817_RIGHT_MLO',
#  'P_00023_RIGHT_MLO',
#  'P_00320_LEFT_CC',
#  'P_00175_RIGHT_CC',
#  'P_01860_RIGHT_CC',
#  'P_01285_RIGHT_MLO',
#  'P_01447_RIGHT_CC',
#  'P_01761_LEFT_MLO',
#  'P_00706_RIGHT_CC',
#  'P_01805_LEFT_MLO',
#  'P_00383_LEFT_MLO',
#  'P_00534_LEFT_CC',
#  'P_01642_RIGHT_CC',
#  'P_00891_RIGHT_CC',
#  'P_01413_RIGHT_CC',
#  'P_01775_LEFT_MLO',
#  'P_01031_LEFT_CC',
#  'P_00004_LEFT_MLO',
#  'P_01036_RIGHT_MLO',
#  'P_01799_LEFT_MLO',
#  'P_01656_LEFT_MLO',
#  'P_01720_RIGHT_MLO',
#  'P_01821_LEFT_MLO',
#  'P_00092_RIGHT_MLO',
#  'P_00716_LEFT_MLO',
#  'P_00496_LEFT_MLO',
#  'P_00320_LEFT_MLO',
#  'P_01373_RIGHT_MLO',
#  'P_00363_LEFT_MLO',
#  'P_00057_RIGHT_MLO',
#  'P_00797_LEFT_MLO',
#  'P_01326_LEFT_MLO',
#  'P_01749_LEFT_CC',
#  'P_00630_LEFT_CC',
#  'P_01324_LEFT_CC',
#  'P_01332_RIGHT_MLO',
#  'P_00442_RIGHT_CC',
#  'P_00519_RIGHT_MLO',
#  'P_00298_LEFT_CC',
#  'P_00303_RIGHT_CC',
#  'P_00549_LEFT_CC',
#  'P_00468_LEFT_CC',
#  'P_00488_LEFT_MLO',
#  'P_00746_LEFT_MLO',
#  'P_01008_RIGHT_CC',
#  'P_01243_LEFT_CC',
#  'P_00313_RIGHT_MLO',
#  'P_00437_LEFT_MLO',
#  'P_01265_RIGHT_CC',
#  'P_01363_RIGHT_MLO',
#  'P_00330_LEFT_MLO',
#  'P_01482_RIGHT_MLO',
#  'P_01735_RIGHT_MLO',
#  'P_01946_RIGHT_CC',
#  'P_00499_RIGHT_CC',
#  'P_00702_RIGHT_CC',
#  'P_00109_LEFT_CC',
#  'P_01517_LEFT_MLO',
#  'P_01831_RIGHT_MLO',
#  'P_01153_RIGHT_CC',
#  'P_01430_RIGHT_MLO',
#  'P_01641_LEFT_CC',
#  'P_01273_RIGHT_MLO',
#  'P_01265_RIGHT_MLO',
#  'P_00927_LEFT_CC',
#  'P_01261_LEFT_MLO',
#  'P_01619_LEFT_MLO',
#  'P_01621_RIGHT_MLO',
#  'P_00319_LEFT_CC',
#  'P_00678_LEFT_MLO',
#  'P_00836_LEFT_MLO',
#  'P_01175_RIGHT_CC',
#  'P_01130_RIGHT_CC',
#  'P_00454_RIGHT_CC',
#  'P_00471_RIGHT_MLO',
#  'P_00694_RIGHT_CC',
#  'P_01261_LEFT_CC',
#  'P_01350_RIGHT_MLO',
#  'P_00450_LEFT_MLO',
#  'P_00034_RIGHT_CC',
#  'P_00074_LEFT_MLO',
#  'P_00675_LEFT_MLO',
#  'P_01305_LEFT_MLO',
#  'P_01356_LEFT_MLO',
#  'P_00604_LEFT_CC',
#  'P_01360_LEFT_CC',
#  'P_00906_LEFT_CC',
#  'P_01814_RIGHT_CC',
#  'P_00332_RIGHT_MLO',
#  'P_00703_LEFT_CC',
#  'P_01164_RIGHT_CC',
#  'P_01844_RIGHT_MLO',
#  'P_00765_RIGHT_CC',
#  'P_00569_RIGHT_CC',
#  'P_00803_LEFT_CC',
#  'P_01715_RIGHT_MLO',
#  'P_00871_LEFT_CC',
#  'P_00717_RIGHT_CC',
#  'P_00133_LEFT_MLO',
#  'P_00385_RIGHT_CC',
#  'P_00617_RIGHT_MLO',
#  'P_00841_RIGHT_CC',
#  'P_00870_LEFT_MLO',
#  'P_00963_LEFT_CC',
#  'P_00644_LEFT_CC',
#  'P_01304_RIGHT_MLO',
#  'P_00332_LEFT_CC',
#  'P_01189_LEFT_MLO',
#  'P_01591_LEFT_CC',
#  'P_00351_LEFT_CC',
#  'P_01632_RIGHT_MLO',
#  'P_01638_RIGHT_MLO',
#  'P_00134_LEFT_CC',
#  'P_01491_RIGHT_MLO',
#  'P_01755_RIGHT_MLO',
#  'P_00775_LEFT_MLO',
#  'P_00187_LEFT_MLO',
#  'P_00661_LEFT_CC',
#  'P_00630_LEFT_MLO',
#  'P_01330_RIGHT_MLO',
#  'P_00517_LEFT_MLO',
#  'P_01367_LEFT_MLO',
#  'P_01427_LEFT_MLO',
#  'P_01583_RIGHT_MLO',
#  'P_01600_RIGHT_CC',
#  'P_00901_RIGHT_MLO',
#  'P_01509_RIGHT_MLO',
#  'P_00437_LEFT_CC',
#  'P_01805_LEFT_CC',
#  'P_00444_LEFT_MLO',
#  'P_01206_RIGHT_MLO',
#  'P_01412_LEFT_CC',
#  'P_00366_RIGHT_MLO',
#  'P_00239_RIGHT_MLO',
#  'P_00566_RIGHT_MLO',
#  'P_00175_RIGHT_MLO',
#  'P_01418_RIGHT_MLO',
#  'P_01301_RIGHT_CC',
#  'P_01831_RIGHT_CC',
#  'P_00616_LEFT_MLO',
#  'P_00417_RIGHT_MLO',
#  'P_00891_RIGHT_MLO',
#  'P_01118_RIGHT_CC',
#  'P_01233_LEFT_CC',
#  'P_01604_LEFT_CC',
#  'P_00484_RIGHT_CC',
#  'P_01788_RIGHT_CC',
#  'P_00902_LEFT_CC',
#  'P_01553_RIGHT_MLO',
#  'P_01394_RIGHT_MLO',
#  'P_01589_LEFT_CC',
#  'P_00982_RIGHT_MLO',
#  'P_00430_LEFT_MLO',
#  'P_00059_LEFT_CC',
#  'P_01442_RIGHT_MLO',
#  'P_00218_LEFT_CC',
#  'P_01642_RIGHT_MLO',
#  'P_00313_RIGHT_CC',
#  'P_01398_LEFT_CC',
#  'P_01581_LEFT_MLO',
#  'P_00356_LEFT_CC',
#  'P_01260_LEFT_MLO',
#  'P_00770_RIGHT_CC',
#  'P_00001_LEFT_CC',
#  'P_00419_RIGHT_CC',
#  'P_01115_RIGHT_CC',
#  'P_01124_RIGHT_CC',
#  'P_01675_RIGHT_MLO',
#  'P_01498_RIGHT_MLO',
#  'P_00597_RIGHT_MLO',
#  'P_01039_LEFT_CC',
#  'P_00475_LEFT_MLO',
#  'P_01233_LEFT_MLO',
#  'P_01754_RIGHT_CC',
#  'P_00695_RIGHT_MLO',
#  'P_00160_RIGHT_MLO',
#  'P_01201_LEFT_CC',
#  'P_01604_LEFT_MLO',
#  'P_01776_RIGHT_MLO',
#  'P_00607_RIGHT_CC',
#  'P_00841_RIGHT_MLO',
#  'P_00065_LEFT_CC',
#  'P_00717_RIGHT_MLO',
#  'P_00961_LEFT_MLO',
#  'P_01386_LEFT_CC',
#  'P_01280_RIGHT_MLO',
#  'P_01299_LEFT_MLO',
#  'P_01540_LEFT_CC',
#  'P_01816_LEFT_MLO',
#  'P_01635_LEFT_CC',
#  'P_00051_LEFT_CC',
#  'P_01634_LEFT_CC',
#  'P_00406_RIGHT_CC',
#  'P_00711_RIGHT_MLO',
#  'P_01097_LEFT_MLO',
#  'P_00746_LEFT_CC',
#  'P_00021_RIGHT_MLO',
#  'P_01340_LEFT_CC',
#  'P_00226_LEFT_MLO',
#  'P_01379_LEFT_CC',
#  'P_00229_LEFT_MLO',
#  'P_01768_LEFT_MLO',
#  'P_00540_LEFT_MLO',
#  'P_01032_RIGHT_CC',
#  'P_01062_RIGHT_MLO',
#  'P_00090_LEFT_CC',
#  'P_00626_LEFT_MLO',
#  'P_01780_LEFT_CC',
#  'P_00814_LEFT_MLO',
#  'P_01270_LEFT_MLO',
#  'P_00564_RIGHT_CC',
#  'P_00421_LEFT_CC',
#  'P_00095_LEFT_MLO',
#  'P_00871_LEFT_MLO',
#  'P_01142_RIGHT_MLO',
#  'P_00920_RIGHT_CC',
#  'P_01485_LEFT_CC',
#  'P_01685_RIGHT_CC',
#  'P_00314_RIGHT_CC',
#  'P_00426_RIGHT_MLO',
#  'P_00061_RIGHT_CC',
#  'P_01701_LEFT_CC',
#  'P_00826_LEFT_MLO',
#  'P_00090_LEFT_MLO',
#  'P_00982_RIGHT_CC',
#  'P_01650_LEFT_MLO',
#  'P_00972_LEFT_MLO',
#  'P_00929_LEFT_CC',
#  'P_00703_LEFT_MLO',
#  'P_01754_RIGHT_MLO',
#  'P_00231_LEFT_MLO',
#  'P_00106_LEFT_MLO',
#  'P_00515_LEFT_MLO',
#  'P_00328_RIGHT_MLO',
#  'P_01051_RIGHT_CC',
#  'P_01190_LEFT_MLO',
#  'P_00917_RIGHT_MLO',
#  'P_01133_RIGHT_CC',
#  'P_01357_LEFT_MLO',
#  'P_01712_LEFT_MLO',
#  'P_01633_RIGHT_CC',
#  'P_00528_RIGHT_MLO',
#  'P_01671_LEFT_MLO',
#  'P_01312_LEFT_CC',
#  'P_01405_RIGHT_MLO',
#  'P_01104_LEFT_MLO',
#  'P_00592_LEFT_CC',
#  'P_00997_LEFT_MLO',
#  'P_01682_LEFT_MLO',
#  'P_00535_LEFT_CC',
#  'P_00051_LEFT_MLO',
#  'P_01801_RIGHT_CC',
#  'P_00818_RIGHT_CC',
#  'P_01612_LEFT_CC',
#  'P_00370_RIGHT_MLO',
#  'P_00120_LEFT_CC',
#  'P_01273_RIGHT_CC',
#  'P_00892_LEFT_MLO',
#  'P_01189_LEFT_CC',
#  'P_01509_RIGHT_CC',
#  'P_01317_RIGHT_MLO',
#  'P_01514_LEFT_MLO',
#  'P_01668_LEFT_MLO',
#  'P_00076_LEFT_CC',
#  'P_01388_LEFT_MLO',
#  'P_01981_RIGHT_MLO',
#  'P_00396_LEFT_CC',
#  'P_00215_RIGHT_CC',
#  'P_00207_LEFT_CC',
#  'P_01876_LEFT_CC',
#  'P_00543_RIGHT_MLO',
#  'P_00666_RIGHT_MLO',
#  'P_01238_RIGHT_CC',
#  'P_01694_RIGHT_CC',
#  'P_00935_LEFT_CC',
#  'P_01062_RIGHT_CC',
#  'P_01441_RIGHT_MLO',
#  'P_00224_LEFT_CC',
#  'P_00149_LEFT_CC',
#  'P_00849_LEFT_CC',
#  'P_01581_LEFT_CC',
#  'P_01841_RIGHT_MLO',
#  'P_01262_RIGHT_MLO',
#  'P_01698_RIGHT_CC',
#  'P_00264_LEFT_MLO',
#  'P_00952_RIGHT_MLO',
#  'P_01849_RIGHT_MLO',
#  'P_00417_RIGHT_CC',
#  'P_01411_RIGHT_MLO',
#  'P_01663_RIGHT_MLO',
#  'P_01461_RIGHT_MLO',
#  'P_00206_RIGHT_MLO',
#  'P_00648_LEFT_CC',
#  'P_01281_RIGHT_MLO',
#  'P_01494_LEFT_MLO',
#  'P_01441_RIGHT_CC',
#  'P_00670_RIGHT_CC',
#  'P_01565_RIGHT_CC',
#  'P_00134_LEFT_MLO',
#  'P_00054_RIGHT_MLO',
#  'P_01481_RIGHT_CC',
#  'P_01103_RIGHT_CC',
#  'P_00802_LEFT_CC',
#  'P_01162_LEFT_MLO',
#  'P_00528_RIGHT_CC',
#  'P_01086_LEFT_MLO',
#  'P_00122_RIGHT_MLO',
#  'P_01093_LEFT_CC',
#  'P_01824_RIGHT_CC',
#  'P_01123_LEFT_CC',
#  'P_01543_RIGHT_MLO',
#  'P_00423_RIGHT_CC',
#  'P_00737_LEFT_CC',
#  'P_00539_RIGHT_MLO',
#  'P_01908_LEFT_CC',
#  'P_00384_RIGHT_CC',
#  'P_01702_RIGHT_MLO',
#  'P_01146_LEFT_CC',
#  'P_00055_LEFT_CC',
#  'P_00208_RIGHT_MLO',
#  'P_00454_RIGHT_MLO',
#  'P_00939_RIGHT_MLO',
#  'P_00512_RIGHT_MLO',
#  'P_01417_RIGHT_MLO',
#  'P_01453_LEFT_MLO',
#  'P_00845_RIGHT_CC',
#  'P_01620_RIGHT_CC',
#  'P_01239_RIGHT_CC',
#  'P_01637_LEFT_MLO',
#  'P_01826_RIGHT_CC',
#  'P_00431_RIGHT_CC',
#  'P_01853_LEFT_MLO',
#  'P_00584_LEFT_MLO',
#  'P_01181_LEFT_CC',
#  'P_01804_LEFT_MLO',
#  'P_01532_LEFT_MLO',
#  'P_01876_LEFT_MLO',
#  'P_01301_RIGHT_MLO',
#  'P_02079_RIGHT_MLO',
#  'P_00224_RIGHT_MLO',
#  'P_00687_LEFT_CC',
#  'P_00978_RIGHT_MLO',
#  'P_01983_LEFT_MLO',
#  'P_00074_RIGHT_MLO',
#  'P_01473_RIGHT_MLO',
#  'P_01163_LEFT_MLO',
#  'P_00160_LEFT_CC',
#  'P_00826_LEFT_CC',
#  'P_00217_LEFT_CC',
#  'P_00949_LEFT_CC',
#  'P_00149_LEFT_MLO',
#  'P_00753_RIGHT_CC',
#  'P_01047_LEFT_MLO',
#  'P_01445_RIGHT_CC',
#  'P_01379_LEFT_MLO',
#  'P_00384_RIGHT_MLO',
#  'P_00205_RIGHT_MLO',
#  'P_01745_RIGHT_MLO',
#  'P_01009_RIGHT_MLO',
#  'P_01231_LEFT_MLO',
#  'P_00634_RIGHT_MLO',
#  'P_01883_LEFT_CC',
#  'P_00218_LEFT_MLO',
#  'P_01241_RIGHT_CC',
#  'P_00898_LEFT_CC',
#  'P_00399_RIGHT_MLO',
#  'P_00436_LEFT_CC',
#  'P_01048_RIGHT_MLO',
#  'P_01190_LEFT_CC',
#  'P_01506_LEFT_MLO',
#  'P_01544_RIGHT_CC',
#  'P_00990_RIGHT_MLO',
#  'P_00572_RIGHT_CC',
#  'P_00978_RIGHT_CC',
#  'P_00413_LEFT_CC',
#  'P_01134_RIGHT_MLO',
#  'P_00499_RIGHT_MLO',
#  'P_00742_LEFT_MLO',
#  'P_01503_LEFT_CC',
#  'P_01572_RIGHT_MLO',
#  'P_01801_RIGHT_MLO',
#  'P_00015_LEFT_MLO',
#  'P_00739_LEFT_CC',
#  'P_00543_RIGHT_CC',
#  'P_02092_LEFT_MLO',
#  'P_01325_RIGHT_MLO',
#  'P_00999_LEFT_MLO',
#  'P_01349_LEFT_MLO',
#  'P_00106_RIGHT_CC',
#  'P_01241_RIGHT_MLO',
#  'P_00205_RIGHT_CC',
#  'P_00886_LEFT_CC',
#  'P_01084_LEFT_CC',
#  'P_01097_LEFT_CC',
#  'P_00172_LEFT_MLO',
#  'P_01824_RIGHT_MLO',
#  'P_00045_LEFT_MLO',
#  'P_00281_LEFT_MLO',
#  'P_01725_RIGHT_CC',
#  'P_00334_LEFT_MLO',
#  'P_00488_LEFT_CC',
#  'P_00984_RIGHT_MLO',
#  'P_01499_RIGHT_MLO',
#  'P_01739_LEFT_CC',
#  'P_00348_LEFT_MLO',
#  'P_00468_LEFT_MLO',
#  'P_01173_RIGHT_CC',
#  'P_01363_RIGHT_CC',
#  'P_00920_RIGHT_MLO',
#  'P_01573_RIGHT_CC',
#  'P_01608_RIGHT_MLO',
#  'P_00128_LEFT_CC',
#  'P_00412_RIGHT_CC',
#  'P_00700_RIGHT_CC',
#  'P_00710_RIGHT_MLO',
#  'P_00828_LEFT_CC',
#  'P_00865_RIGHT_MLO',
#  'P_01654_RIGHT_MLO',
#  'P_01076_RIGHT_CC',
#  'P_00702_RIGHT_MLO',
#  'P_01611_RIGHT_MLO',
#  'P_00779_LEFT_MLO',
#  'P_00187_LEFT_CC',
#  'P_00096_RIGHT_MLO',
#  'P_00526_RIGHT_MLO',
#  'P_00950_LEFT_CC',
#  'P_01373_RIGHT_CC',
#  'P_01890_LEFT_MLO',
#  'P_00515_RIGHT_CC',
#  'P_00279_LEFT_CC',
#  'P_01388_LEFT_CC',
#  'P_01112_LEFT_CC',
#  'P_01434_LEFT_MLO',
#  'P_00086_RIGHT_MLO',
#  'P_01714_RIGHT_MLO',
#  'P_00172_LEFT_CC',
#  'P_00596_RIGHT_CC',
#  'P_01232_RIGHT_MLO',
#  'P_01034_RIGHT_MLO',
#  'P_00328_RIGHT_CC',
#  'P_00495_RIGHT_MLO',
#  'P_00058_RIGHT_CC',
#  'P_00665_LEFT_MLO',
#  'P_00776_RIGHT_CC',
#  'P_01391_LEFT_CC',
#  'P_01394_LEFT_MLO',
#  'P_01669_LEFT_CC',
#  'P_01035_RIGHT_MLO',
#  'P_01780_LEFT_MLO',
#  'P_00289_LEFT_CC',
#  'P_00968_LEFT_MLO',
#  'P_01877_LEFT_MLO',
#  'P_00471_RIGHT_CC',
#  'P_00096_RIGHT_CC',
#  'P_00568_LEFT_CC',
#  'P_01712_RIGHT_MLO',
#  'P_00913_LEFT_CC',
#  'P_00462_LEFT_MLO',
#  'P_01674_LEFT_CC',
#  'P_01493_RIGHT_CC',
#  'P_01600_RIGHT_MLO',
#  'P_01803_RIGHT_MLO',
#  'P_00719_LEFT_CC',
#  'P_01051_RIGHT_MLO',
#  'P_01304_RIGHT_CC',
#  'P_01439_LEFT_CC',
#  'P_00023_RIGHT_CC',
#  'P_00726_RIGHT_MLO',
#  'P_01474_RIGHT_CC',
#  'P_00420_RIGHT_MLO',
#  'P_01633_RIGHT_MLO',
#  'P_00958_LEFT_MLO',
#  'P_00241_RIGHT_CC',
#  'P_00199_LEFT_MLO',
#  'P_00526_RIGHT_CC',
#  'P_00568_LEFT_MLO',
#  'P_00765_RIGHT_MLO',
#  'P_01070_LEFT_CC',
#  'P_00018_RIGHT_MLO',
#  'P_00715_RIGHT_MLO',
#  'P_00076_LEFT_MLO',
#  'P_00959_RIGHT_MLO',
#  'P_01630_RIGHT_MLO',
#  'P_02033_RIGHT_CC',
#  'P_01461_RIGHT_CC',
#  'P_00710_LEFT_CC',
#  'P_02033_RIGHT_MLO',
#  'P_01790_LEFT_CC',
#  'P_01612_LEFT_MLO',
#  'P_01231_LEFT_CC',
#  'P_01589_LEFT_MLO',
#  'P_01888_RIGHT_MLO',
#  'P_00640_RIGHT_CC',
#  'P_00810_RIGHT_MLO',
#  'P_01739_RIGHT_CC',
#  'P_00881_LEFT_CC',
#  'P_00659_RIGHT_MLO',
#  'P_00778_RIGHT_CC',
#  'P_01297_LEFT_CC',
#  'P_01144_LEFT_CC',
#  'P_00731_RIGHT_MLO',
#  'P_01178_RIGHT_CC',
#  'P_00314_RIGHT_MLO',
#  'P_01144_LEFT_MLO',
#  'P_02079_RIGHT_CC',
#  'P_00224_RIGHT_CC',
#  'P_00801_LEFT_MLO',
#  'P_01635_LEFT_MLO',
#  'P_00027_RIGHT_CC',
#  'P_00094_RIGHT_CC',
#  'P_01221_LEFT_CC',
#  'P_00607_RIGHT_MLO',
#  'P_01173_RIGHT_MLO',
#  'P_00283_RIGHT_CC',
#  'P_01621_RIGHT_CC',
#  'P_01785_RIGHT_MLO',
#  'P_01230_LEFT_MLO',
#  'P_00094_RIGHT_MLO',
#  'P_01613_LEFT_MLO',
#  'P_01452_RIGHT_CC',
#  'P_01439_LEFT_MLO',
#  'P_01076_RIGHT_MLO',
#  'P_01650_LEFT_CC',
#  'P_00439_RIGHT_MLO',
#  'P_01008_RIGHT_MLO',
#  'P_01283_RIGHT_MLO',
#  'P_01394_LEFT_CC',
#  'P_00419_LEFT_CC',
#  'P_01178_RIGHT_MLO',
#  'P_00700_RIGHT_MLO',
#  'P_01889_RIGHT_CC',
#  'P_00133_LEFT_CC',
#  'P_00851_LEFT_MLO',
#  'P_01039_RIGHT_CC',
#  'P_01447_RIGHT_MLO',
#  'P_00309_LEFT_MLO',
#  'P_00794_LEFT_CC',
#  'P_00814_LEFT_CC',
#  'P_00711_RIGHT_CC',
#  'P_00742_LEFT_CC',
#  'P_00110_RIGHT_CC',
#  'P_00236_RIGHT_MLO',
#  'P_00406_RIGHT_MLO',
#  'P_00534_LEFT_MLO',
#  'P_00728_RIGHT_CC',
#  'P_01054_RIGHT_MLO',
#  'P_00332_RIGHT_CC',
#  'P_00660_LEFT_CC',
#  'P_00009_RIGHT_MLO',
#  'P_00894_RIGHT_MLO',
#  'P_01413_RIGHT_MLO',
#  'P_01426_RIGHT_CC',
#  'P_01138_RIGHT_MLO',
#  'P_01656_LEFT_CC',
#  'P_01654_RIGHT_CC',
#  'P_00726_RIGHT_CC',
#  'P_00441_RIGHT_MLO',
#  'P_00081_RIGHT_MLO',
#  'P_01165_LEFT_CC',
#  'P_01332_RIGHT_CC',
#  'P_01504_LEFT_MLO',
#  'P_01682_LEFT_CC',
#  'P_00512_RIGHT_CC',
#  'P_01531_RIGHT_MLO',
#  'P_00648_LEFT_MLO',
#  'P_00146_RIGHT_CC',
#  'P_01382_LEFT_MLO',
#  'P_00849_LEFT_MLO',
#  'P_01850_RIGHT_MLO',
#  'P_00081_RIGHT_CC',
#  'P_01644_RIGHT_MLO',
#  'P_01739_RIGHT_MLO',
#  'P_01485_LEFT_MLO',
#  'P_00532_LEFT_CC',
#  'P_01744_LEFT_MLO',
#  'P_00653_LEFT_MLO',
#  'P_00160_LEFT_MLO',
#  'P_00733_RIGHT_MLO',
#  'P_01644_LEFT_MLO',
#  'P_01504_LEFT_CC',
#  'P_00166_RIGHT_MLO',
#  'P_00492_RIGHT_MLO',
#  'P_00021_RIGHT_CC',
#  'P_00294_LEFT_CC',
#  'P_00431_RIGHT_MLO',
#  'P_00823_RIGHT_MLO',
#  'P_01279_LEFT_CC',
#  'P_01544_RIGHT_MLO',
#  'P_00640_RIGHT_MLO',
#  'P_01638_RIGHT_CC',
#  'P_00021_LEFT_MLO',
#  'P_00283_RIGHT_MLO',
#  'P_00611_RIGHT_MLO',
#  'P_01702_RIGHT_CC',
#  'P_00247_RIGHT_CC',
#  'P_00901_RIGHT_CC',
#  'P_01816_LEFT_CC',
#  'P_00370_RIGHT_CC',
#  'P_01142_RIGHT_CC',
#  'P_00634_LEFT_MLO',
#  'P_00698_RIGHT_CC',
#  'P_00764_RIGHT_CC',
#  'P_00419_RIGHT_MLO',
#  'P_00554_LEFT_CC',
#  'P_01212_RIGHT_CC',
#  'P_00106_RIGHT_MLO',
#  'P_01175_LEFT_MLO',
#  'P_01203_RIGHT_MLO',
#  'P_00259_RIGHT_MLO',
#  'P_01150_LEFT_MLO',
#  'P_01821_LEFT_CC',
#  'P_01423_RIGHT_MLO',
#  'P_00816_RIGHT_CC',
#  'P_00273_LEFT_CC',
#  'P_01671_LEFT_CC',
#  'P_01710_LEFT_MLO',
#  'P_00041_LEFT_CC',
#  'P_00634_LEFT_CC',
#  'P_01034_RIGHT_CC',
#  'P_00235_RIGHT_MLO',
#  'P_00303_LEFT_MLO',
#  'P_00342_RIGHT_MLO',
#  'P_01163_LEFT_CC',
#  'P_01039_RIGHT_MLO',
#  'P_01155_RIGHT_MLO',
#  'P_01454_LEFT_MLO',
#  'P_01079_RIGHT_CC',
#  'P_00870_LEFT_CC',
#  'P_00670_RIGHT_MLO',
#  'P_00304_LEFT_MLO',
#  'P_00414_LEFT_CC',
#  'P_00747_LEFT_MLO',
#  'P_00739_LEFT_MLO',
#  'P_01529_RIGHT_MLO',
#  'P_00401_LEFT_CC',
#  'P_00110_LEFT_CC',
#  'P_01768_LEFT_CC',
#  'P_00927_LEFT_MLO',
#  'P_00376_RIGHT_CC',
#  'P_00363_LEFT_CC',
#  'P_00259_RIGHT_CC',
#  'P_01715_RIGHT_CC',
#  'P_01802_LEFT_MLO',
#  'P_00415_RIGHT_MLO',
#  'P_00939_RIGHT_CC',
#  'P_01084_LEFT_MLO',
#  'P_01149_RIGHT_MLO',
#  'P_01559_RIGHT_MLO',
#  ...}

# %%
mass_all_df.head(50)
# Out:
#    patient_id  breast_density left_or_right_breast image_view  abnormality_id  \
# 0     P_00001               3                 LEFT         CC               1
# 1     P_00001               3                 LEFT        MLO               1
# 2     P_00004               3                 LEFT         CC               1
# 3     P_00004               3                 LEFT        MLO               1
# 4     P_00004               3                RIGHT        MLO               1
# 5     P_00009               3                RIGHT         CC               1
# 6     P_00009               3                RIGHT        MLO               1
# 7     P_00015               3                 LEFT        MLO               1
# 8     P_00018               2                RIGHT         CC               1
# 9     P_00018               2                RIGHT        MLO               1
# 10    P_00021               1                 LEFT         CC               1
# 11    P_00021               1                 LEFT        MLO               1
# 12    P_00021               1                RIGHT         CC               1
# 13    P_00021               1                RIGHT        MLO               1
# 14    P_00023               1                RIGHT         CC               1
# 15    P_00023               1                RIGHT        MLO               1
# 16    P_00026               2                 LEFT         CC               1
# 17    P_00026               2                 LEFT        MLO               1
# 18    P_00027               2                RIGHT         CC               1
# 19    P_00027               2                RIGHT        MLO               1
# 20    P_00034               3                RIGHT         CC               1
# 21    P_00034               3                RIGHT        MLO               1
# 22    P_00039               2                RIGHT         CC               1
# 23    P_00039               2                RIGHT        MLO               1
# 24    P_00041               1                 LEFT         CC               1
# 25    P_00041               1                 LEFT        MLO               1
# 26    P_00044               2                RIGHT         CC               1
# 27    P_00044               2                RIGHT         CC               2
# 28    P_00044               2                RIGHT         CC               3
# 29    P_00044               2                RIGHT         CC               4
# 30    P_00044               2                RIGHT        MLO               1
# 31    P_00044               2                RIGHT        MLO               2
# 32    P_00045               4                 LEFT         CC               1
# 33    P_00045               4                 LEFT        MLO               1
# 34    P_00046               3                RIGHT        MLO               1
# 35    P_00051               2                 LEFT         CC               1
# 36    P_00051               2                 LEFT        MLO               1
# 37    P_00054               4                RIGHT        MLO               1
# 38    P_00055               2                 LEFT         CC               1
# 39    P_00057               1                RIGHT         CC               1
# 40    P_00057               1                RIGHT        MLO               1
# 41    P_00058               2                RIGHT         CC               1
# 42    P_00059               1                 LEFT         CC               1
# 43    P_00059               1                 LEFT        MLO               1
# 44    P_00061               2                RIGHT         CC               1
# 45    P_00061               2                RIGHT        MLO               1
# 46    P_00064               3                RIGHT        MLO               1
# 47    P_00065               2                 LEFT         CC               1
# 48    P_00065               2                 LEFT        MLO               1
# 49    P_00068               3                RIGHT         CC               1
#
#    abnormality_type                          mass_shape  \
# 0              mass  IRREGULAR-ARCHITECTURAL_DISTORTION
# 1              mass  IRREGULAR-ARCHITECTURAL_DISTORTION
# 2              mass            ARCHITECTURAL_DISTORTION
# 3              mass            ARCHITECTURAL_DISTORTION
# 4              mass                                OVAL
# 5              mass                                OVAL
# 6              mass                                OVAL
# 7              mass                           IRREGULAR
# 8              mass                                OVAL
# 9              mass                                OVAL
# 10             mass                                OVAL
# 11             mass                                OVAL
# 12             mass                                OVAL
# 13             mass                                OVAL
# 14             mass                           IRREGULAR
# 15             mass                           IRREGULAR
# 16             mass                                OVAL
# 17             mass                                OVAL
# 18             mass                                OVAL
# 19             mass                                OVAL
# 20             mass                           IRREGULAR
# 21             mass                           IRREGULAR
# 22             mass                           IRREGULAR
# 23             mass                           IRREGULAR
# 24             mass                          LYMPH_NODE
# 25             mass                LOBULATED-LYMPH_NODE
# 26             mass                                OVAL
# 27             mass                                OVAL
# 28             mass                                OVAL
# 29             mass                           LOBULATED
# 30             mass                           LOBULATED
# 31             mass                                OVAL
# 32             mass            FOCAL_ASYMMETRIC_DENSITY
# 33             mass            FOCAL_ASYMMETRIC_DENSITY
# 34             mass                           IRREGULAR
# 35             mass                           IRREGULAR
# 36             mass                           IRREGULAR
# 37             mass                                OVAL
# 38             mass                           LOBULATED
# 39             mass                                OVAL
# 40             mass                                OVAL
# 41             mass                           IRREGULAR
# 42             mass                                OVAL
# 43             mass                                OVAL
# 44             mass                           LOBULATED
# 45             mass                                OVAL
# 46             mass            FOCAL_ASYMMETRIC_DENSITY
# 47             mass                                OVAL
# 48             mass                                OVAL
# 49             mass                           IRREGULAR
#
#               mass_margins  assessment                pathology  subtlety  \
# 0               SPICULATED           4                MALIGNANT         4
# 1               SPICULATED           4                MALIGNANT         4
# 2              ILL_DEFINED           4                   BENIGN         3
# 3              ILL_DEFINED           4                   BENIGN         3
# 4            CIRCUMSCRIBED           4                   BENIGN         5
# 5              ILL_DEFINED           4                MALIGNANT         4
# 6              ILL_DEFINED           4                MALIGNANT         4
# 7   ILL_DEFINED-SPICULATED           4                MALIGNANT         4
# 8            CIRCUMSCRIBED           4                   BENIGN         5
# 9            CIRCUMSCRIBED           4                   BENIGN         5
# 10           CIRCUMSCRIBED           3                   BENIGN         5
# 11           CIRCUMSCRIBED           3                   BENIGN         5
# 12           CIRCUMSCRIBED           3                   BENIGN         5
# 13           CIRCUMSCRIBED           3                   BENIGN         5
# 14              SPICULATED           5                MALIGNANT         4
# 15              SPICULATED           5                MALIGNANT         4
# 16                OBSCURED           3                   BENIGN         3
# 17                OBSCURED           3                   BENIGN         3
# 18             ILL_DEFINED           4                   BENIGN         3
# 19           CIRCUMSCRIBED           4                   BENIGN         4
# 20              SPICULATED           5                MALIGNANT         4
# 21              SPICULATED           5                MALIGNANT         4
# 22              SPICULATED           5                MALIGNANT         5
# 23              SPICULATED           5                MALIGNANT         5
# 24           CIRCUMSCRIBED           2  BENIGN_WITHOUT_CALLBACK         5
# 25           CIRCUMSCRIBED           2  BENIGN_WITHOUT_CALLBACK         5
# 26           CIRCUMSCRIBED           3                   BENIGN         5
# 27           CIRCUMSCRIBED           3                   BENIGN         5
# 28           CIRCUMSCRIBED           3                   BENIGN         5
# 29           CIRCUMSCRIBED           3                   BENIGN         5
# 30           CIRCUMSCRIBED           3                   BENIGN         5
# 31           CIRCUMSCRIBED           3                   BENIGN         5
# 32             ILL_DEFINED           4                MALIGNANT         3
# 33             ILL_DEFINED           4                MALIGNANT         3
# 34    OBSCURED-ILL_DEFINED           3                MALIGNANT         1
# 35              SPICULATED           5                MALIGNANT         5
# 36              SPICULATED           5                MALIGNANT         5
# 37           CIRCUMSCRIBED           3  BENIGN_WITHOUT_CALLBACK         4
# 38           CIRCUMSCRIBED           0                   BENIGN         3
# 39              SPICULATED           5                MALIGNANT         5
# 40              SPICULATED           5                MALIGNANT         5
# 41             ILL_DEFINED           4                MALIGNANT         4
# 42                OBSCURED           3                MALIGNANT         4
# 43                OBSCURED           3                MALIGNANT         4
# 44           CIRCUMSCRIBED           3                   BENIGN         4
# 45           CIRCUMSCRIBED           3                   BENIGN         4
# 46             ILL_DEFINED           3  BENIGN_WITHOUT_CALLBACK         4
# 47                OBSCURED           0                   BENIGN         5
# 48                OBSCURED           0                   BENIGN         5
# 49              SPICULATED           4                MALIGNANT         4
#
#                                       image_file_path  \
# 0   Mass-Training_P_00001_LEFT_CC/1.3.6.1.4.1.9590...
# 1   Mass-Training_P_00001_LEFT_MLO/1.3.6.1.4.1.959...
# 2   Mass-Training_P_00004_LEFT_CC/1.3.6.1.4.1.9590...
# 3   Mass-Training_P_00004_LEFT_MLO/1.3.6.1.4.1.959...
# 4   Mass-Training_P_00004_RIGHT_MLO/1.3.6.1.4.1.95...
# 5   Mass-Training_P_00009_RIGHT_CC/1.3.6.1.4.1.959...
# 6   Mass-Training_P_00009_RIGHT_MLO/1.3.6.1.4.1.95...
# 7   Mass-Training_P_00015_LEFT_MLO/1.3.6.1.4.1.959...
# 8   Mass-Training_P_00018_RIGHT_CC/1.3.6.1.4.1.959...
# 9   Mass-Training_P_00018_RIGHT_MLO/1.3.6.1.4.1.95...
# 10  Mass-Training_P_00021_LEFT_CC/1.3.6.1.4.1.9590...
# 11  Mass-Training_P_00021_LEFT_MLO/1.3.6.1.4.1.959...
# 12  Mass-Training_P_00021_RIGHT_CC/1.3.6.1.4.1.959...
# 13  Mass-Training_P_00021_RIGHT_MLO/1.3.6.1.4.1.95...
# 14  Mass-Training_P_00023_RIGHT_CC/1.3.6.1.4.1.959...
# 15  Mass-Training_P_00023_RIGHT_MLO/1.3.6.1.4.1.95...
# 16  Mass-Training_P_00026_LEFT_CC/1.3.6.1.4.1.9590...
# 17  Mass-Training_P_00026_LEFT_MLO/1.3.6.1.4.1.959...
# 18  Mass-Training_P_00027_RIGHT_CC/1.3.6.1.4.1.959...
# 19  Mass-Training_P_00027_RIGHT_MLO/1.3.6.1.4.1.95...
# 20  Mass-Training_P_00034_RIGHT_CC/1.3.6.1.4.1.959...
# 21  Mass-Training_P_00034_RIGHT_MLO/1.3.6.1.4.1.95...
# 22  Mass-Training_P_00039_RIGHT_CC/1.3.6.1.4.1.959...
# 23  Mass-Training_P_00039_RIGHT_MLO/1.3.6.1.4.1.95...
# 24  Mass-Training_P_00041_LEFT_CC/1.3.6.1.4.1.9590...
# 25  Mass-Training_P_00041_LEFT_MLO/1.3.6.1.4.1.959...
# 26  Mass-Training_P_00044_RIGHT_CC/1.3.6.1.4.1.959...
# 27  Mass-Training_P_00044_RIGHT_CC/1.3.6.1.4.1.959...
# 28  Mass-Training_P_00044_RIGHT_CC/1.3.6.1.4.1.959...
# 29  Mass-Training_P_00044_RIGHT_CC/1.3.6.1.4.1.959...
# 30  Mass-Training_P_00044_RIGHT_MLO/1.3.6.1.4.1.95...
# 31  Mass-Training_P_00044_RIGHT_MLO/1.3.6.1.4.1.95...
# 32  Mass-Training_P_00045_LEFT_CC/1.3.6.1.4.1.9590...
# 33  Mass-Training_P_00045_LEFT_MLO/1.3.6.1.4.1.959...
# 34  Mass-Training_P_00046_RIGHT_MLO/1.3.6.1.4.1.95...
# 35  Mass-Training_P_00051_LEFT_CC/1.3.6.1.4.1.9590...
# 36  Mass-Training_P_00051_LEFT_MLO/1.3.6.1.4.1.959...
# 37  Mass-Training_P_00054_RIGHT_MLO/1.3.6.1.4.1.95...
# 38  Mass-Training_P_00055_LEFT_CC/1.3.6.1.4.1.9590...
# 39  Mass-Training_P_00057_RIGHT_CC/1.3.6.1.4.1.959...
# 40  Mass-Training_P_00057_RIGHT_MLO/1.3.6.1.4.1.95...
# 41  Mass-Training_P_00058_RIGHT_CC/1.3.6.1.4.1.959...
# 42  Mass-Training_P_00059_LEFT_CC/1.3.6.1.4.1.9590...
# 43  Mass-Training_P_00059_LEFT_MLO/1.3.6.1.4.1.959...
# 44  Mass-Training_P_00061_RIGHT_CC/1.3.6.1.4.1.959...
# 45  Mass-Training_P_00061_RIGHT_MLO/1.3.6.1.4.1.95...
# 46  Mass-Training_P_00064_RIGHT_MLO/1.3.6.1.4.1.95...
# 47  Mass-Training_P_00065_LEFT_CC/1.3.6.1.4.1.9590...
# 48  Mass-Training_P_00065_LEFT_MLO/1.3.6.1.4.1.959...
# 49  Mass-Training_P_00068_RIGHT_CC/1.3.6.1.4.1.959...
#
#                               cropped_image_file_path  \
# 0   Mass-Training_P_00001_LEFT_CC_1/1.3.6.1.4.1.95...
# 1   Mass-Training_P_00001_LEFT_MLO_1/1.3.6.1.4.1.9...
# 2   Mass-Training_P_00004_LEFT_CC_1/1.3.6.1.4.1.95...
# 3   Mass-Training_P_00004_LEFT_MLO_1/1.3.6.1.4.1.9...
# 4   Mass-Training_P_00004_RIGHT_MLO_1/1.3.6.1.4.1....
# 5   Mass-Training_P_00009_RIGHT_CC_1/1.3.6.1.4.1.9...
# 6   Mass-Training_P_00009_RIGHT_MLO_1/1.3.6.1.4.1....
# 7   Mass-Training_P_00015_LEFT_MLO_1/1.3.6.1.4.1.9...
# 8   Mass-Training_P_00018_RIGHT_CC_1/1.3.6.1.4.1.9...
# 9   Mass-Training_P_00018_RIGHT_MLO_1/1.3.6.1.4.1....
# 10  Mass-Training_P_00021_LEFT_CC_1/1.3.6.1.4.1.95...
# 11  Mass-Training_P_00021_LEFT_MLO_1/1.3.6.1.4.1.9...
# 12  Mass-Training_P_00021_RIGHT_CC_1/1.3.6.1.4.1.9...
# 13  Mass-Training_P_00021_RIGHT_MLO_1/1.3.6.1.4.1....
# 14  Mass-Training_P_00023_RIGHT_CC_1/1.3.6.1.4.1.9...
# 15  Mass-Training_P_00023_RIGHT_MLO_1/1.3.6.1.4.1....
# 16  Mass-Training_P_00026_LEFT_CC_1/1.3.6.1.4.1.95...
# 17  Mass-Training_P_00026_LEFT_MLO_1/1.3.6.1.4.1.9...
# 18  Mass-Training_P_00027_RIGHT_CC_1/1.3.6.1.4.1.9...
# 19  Mass-Training_P_00027_RIGHT_MLO_1/1.3.6.1.4.1....
# 20  Mass-Training_P_00034_RIGHT_CC_1/1.3.6.1.4.1.9...
# 21  Mass-Training_P_00034_RIGHT_MLO_1/1.3.6.1.4.1....
# 22  Mass-Training_P_00039_RIGHT_CC_1/1.3.6.1.4.1.9...
# 23  Mass-Training_P_00039_RIGHT_MLO_1/1.3.6.1.4.1....
# 24  Mass-Training_P_00041_LEFT_CC_1/1.3.6.1.4.1.95...
# 25  Mass-Training_P_00041_LEFT_MLO_1/1.3.6.1.4.1.9...
# 26  Mass-Training_P_00044_RIGHT_CC_1/1.3.6.1.4.1.9...
# 27  Mass-Training_P_00044_RIGHT_CC_2/1.3.6.1.4.1.9...
# 28  Mass-Training_P_00044_RIGHT_CC_3/1.3.6.1.4.1.9...
# 29  Mass-Training_P_00044_RIGHT_CC_4/1.3.6.1.4.1.9...
# 30  Mass-Training_P_00044_RIGHT_MLO_1/1.3.6.1.4.1....
# 31  Mass-Training_P_00044_RIGHT_MLO_2/1.3.6.1.4.1....
# 32  Mass-Training_P_00045_LEFT_CC_1/1.3.6.1.4.1.95...
# 33  Mass-Training_P_00045_LEFT_MLO_1/1.3.6.1.4.1.9...
# 34  Mass-Training_P_00046_RIGHT_MLO_1/1.3.6.1.4.1....
# 35  Mass-Training_P_00051_LEFT_CC_1/1.3.6.1.4.1.95...
# 36  Mass-Training_P_00051_LEFT_MLO_1/1.3.6.1.4.1.9...
# 37  Mass-Training_P_00054_RIGHT_MLO_1/1.3.6.1.4.1....
# 38  Mass-Training_P_00055_LEFT_CC_1/1.3.6.1.4.1.95...
# 39  Mass-Training_P_00057_RIGHT_CC_1/1.3.6.1.4.1.9...
# 40  Mass-Training_P_00057_RIGHT_MLO_1/1.3.6.1.4.1....
# 41  Mass-Training_P_00058_RIGHT_CC_1/1.3.6.1.4.1.9...
# 42  Mass-Training_P_00059_LEFT_CC_1/1.3.6.1.4.1.95...
# 43  Mass-Training_P_00059_LEFT_MLO_1/1.3.6.1.4.1.9...
# 44  Mass-Training_P_00061_RIGHT_CC_1/1.3.6.1.4.1.9...
# 45  Mass-Training_P_00061_RIGHT_MLO_1/1.3.6.1.4.1....
# 46  Mass-Training_P_00064_RIGHT_MLO_1/1.3.6.1.4.1....
# 47  Mass-Training_P_00065_LEFT_CC_1/1.3.6.1.4.1.95...
# 48  Mass-Training_P_00065_LEFT_MLO_1/1.3.6.1.4.1.9...
# 49  Mass-Training_P_00068_RIGHT_CC_1/1.3.6.1.4.1.9...
#
#                                    ROI_mask_file_path         identifier
# 0   Mass-Training_P_00001_LEFT_CC_1/1.3.6.1.4.1.95...    P_00001_LEFT_CC
# 1   Mass-Training_P_00001_LEFT_MLO_1/1.3.6.1.4.1.9...   P_00001_LEFT_MLO
# 2   Mass-Training_P_00004_LEFT_CC_1/1.3.6.1.4.1.95...    P_00004_LEFT_CC
# 3   Mass-Training_P_00004_LEFT_MLO_1/1.3.6.1.4.1.9...   P_00004_LEFT_MLO
# 4   Mass-Training_P_00004_RIGHT_MLO_1/1.3.6.1.4.1....  P_00004_RIGHT_MLO
# 5   Mass-Training_P_00009_RIGHT_CC_1/1.3.6.1.4.1.9...   P_00009_RIGHT_CC
# 6   Mass-Training_P_00009_RIGHT_MLO_1/1.3.6.1.4.1....  P_00009_RIGHT_MLO
# 7   Mass-Training_P_00015_LEFT_MLO_1/1.3.6.1.4.1.9...   P_00015_LEFT_MLO
# 8   Mass-Training_P_00018_RIGHT_CC_1/1.3.6.1.4.1.9...   P_00018_RIGHT_CC
# 9   Mass-Training_P_00018_RIGHT_MLO_1/1.3.6.1.4.1....  P_00018_RIGHT_MLO
# 10  Mass-Training_P_00021_LEFT_CC_1/1.3.6.1.4.1.95...    P_00021_LEFT_CC
# 11  Mass-Training_P_00021_LEFT_MLO_1/1.3.6.1.4.1.9...   P_00021_LEFT_MLO
# 12  Mass-Training_P_00021_RIGHT_CC_1/1.3.6.1.4.1.9...   P_00021_RIGHT_CC
# 13  Mass-Training_P_00021_RIGHT_MLO_1/1.3.6.1.4.1....  P_00021_RIGHT_MLO
# 14  Mass-Training_P_00023_RIGHT_CC_1/1.3.6.1.4.1.9...   P_00023_RIGHT_CC
# 15  Mass-Training_P_00023_RIGHT_MLO_1/1.3.6.1.4.1....  P_00023_RIGHT_MLO
# 16  Mass-Training_P_00026_LEFT_CC_1/1.3.6.1.4.1.95...    P_00026_LEFT_CC
# 17  Mass-Training_P_00026_LEFT_MLO_1/1.3.6.1.4.1.9...   P_00026_LEFT_MLO
# 18  Mass-Training_P_00027_RIGHT_CC_1/1.3.6.1.4.1.9...   P_00027_RIGHT_CC
# 19  Mass-Training_P_00027_RIGHT_MLO_1/1.3.6.1.4.1....  P_00027_RIGHT_MLO
# 20  Mass-Training_P_00034_RIGHT_CC_1/1.3.6.1.4.1.9...   P_00034_RIGHT_CC
# 21  Mass-Training_P_00034_RIGHT_MLO_1/1.3.6.1.4.1....  P_00034_RIGHT_MLO
# 22  Mass-Training_P_00039_RIGHT_CC_1/1.3.6.1.4.1.9...   P_00039_RIGHT_CC
# 23  Mass-Training_P_00039_RIGHT_MLO_1/1.3.6.1.4.1....  P_00039_RIGHT_MLO
# 24  Mass-Training_P_00041_LEFT_CC_1/1.3.6.1.4.1.95...    P_00041_LEFT_CC
# 25  Mass-Training_P_00041_LEFT_MLO_1/1.3.6.1.4.1.9...   P_00041_LEFT_MLO
# 26  Mass-Training_P_00044_RIGHT_CC_1/1.3.6.1.4.1.9...   P_00044_RIGHT_CC
# 27  Mass-Training_P_00044_RIGHT_CC_2/1.3.6.1.4.1.9...   P_00044_RIGHT_CC
# 28  Mass-Training_P_00044_RIGHT_CC_3/1.3.6.1.4.1.9...   P_00044_RIGHT_CC
# 29  Mass-Training_P_00044_RIGHT_CC_4/1.3.6.1.4.1.9...   P_00044_RIGHT_CC
# 30  Mass-Training_P_00044_RIGHT_MLO_1/1.3.6.1.4.1....  P_00044_RIGHT_MLO
# 31  Mass-Training_P_00044_RIGHT_MLO_2/1.3.6.1.4.1....  P_00044_RIGHT_MLO
# 32  Mass-Training_P_00045_LEFT_CC_1/1.3.6.1.4.1.95...    P_00045_LEFT_CC
# 33  Mass-Training_P_00045_LEFT_MLO_1/1.3.6.1.4.1.9...   P_00045_LEFT_MLO
# 34  Mass-Training_P_00046_RIGHT_MLO_1/1.3.6.1.4.1....  P_00046_RIGHT_MLO
# 35  Mass-Training_P_00051_LEFT_CC_1/1.3.6.1.4.1.95...    P_00051_LEFT_CC
# 36  Mass-Training_P_00051_LEFT_MLO_1/1.3.6.1.4.1.9...   P_00051_LEFT_MLO
# 37  Mass-Training_P_00054_RIGHT_MLO_1/1.3.6.1.4.1....  P_00054_RIGHT_MLO
# 38  Mass-Training_P_00055_LEFT_CC_1/1.3.6.1.4.1.95...    P_00055_LEFT_CC
# 39  Mass-Training_P_00057_RIGHT_CC_1/1.3.6.1.4.1.9...   P_00057_RIGHT_CC
# 40  Mass-Training_P_00057_RIGHT_MLO_1/1.3.6.1.4.1....  P_00057_RIGHT_MLO
# 41  Mass-Training_P_00058_RIGHT_CC_1/1.3.6.1.4.1.9...   P_00058_RIGHT_CC
# 42  Mass-Training_P_00059_LEFT_CC_1/1.3.6.1.4.1.95...    P_00059_LEFT_CC
# 43  Mass-Training_P_00059_LEFT_MLO_1/1.3.6.1.4.1.9...   P_00059_LEFT_MLO
# 44  Mass-Training_P_00061_RIGHT_CC_1/1.3.6.1.4.1.9...   P_00061_RIGHT_CC
# 45  Mass-Training_P_00061_RIGHT_MLO_1/1.3.6.1.4.1....  P_00061_RIGHT_MLO
# 46  Mass-Training_P_00064_RIGHT_MLO_1/1.3.6.1.4.1....  P_00064_RIGHT_MLO
# 47  Mass-Training_P_00065_LEFT_CC_1/1.3.6.1.4.1.95...    P_00065_LEFT_CC
# 48  Mass-Training_P_00065_LEFT_MLO_1/1.3.6.1.4.1.9...   P_00065_LEFT_MLO
# 49  Mass-Training_P_00068_RIGHT_CC_1/1.3.6.1.4.1.9...   P_00068_RIGHT_CC

# %%
# all_df = pd.concat(objs=[calc_all_df, mass_all_df])

# %%
# all_df.to_csv("/Users/cleonwong/Desktop/Code/mammogram-cv/data/csv/mass_calc_all.csv", index=False)

# %% [markdown]
# ### Abnormality type

# %%
plot_df = mass_all_df["abnormality_type"].value_counts()

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(7, 5))
plot_df.plot.bar(ax=ax, color="#d3d3d3", edgecolor="black")

# ax.set_title("Distribution of pathology-abnormality_type.")
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.grid(b=True, which="major", axis="y", color="#d3d3d3", linestyle="-")
ax.grid(b=True, which="minor", axis="y", color="#e7e7e7", linestyle="dashed")
ax.set_ylabel("Count")
ax.set_xticklabels(labels=ax.get_xticklabels(), rotation=0, ha="center")
ax.yaxis.set_ticks(np.arange(0, 2250, 250))
# ax.yaxis.set_minor_locator(MultipleLocator(50))
ax.patch.set_alpha(0)
ax.set_axisbelow(True)

# plt.savefig("/Users/cleonwong/Google Drive/To-Share/mammogram_medium_article/Part1/calc_mass.png", dpi=300, transparent=True)

# %% [markdown]
# ### Mammograms with >1 abnormalities

# %%
temp = mass_all_df.loc[mass_all_df["abnormality_type"] == "mass"]["identifier"].value_counts()

to_plot_dict = {"1 Mass Abnormality":0, ">1 Mass Abnormality":0}

for count in temp:
    if count > 1:
        to_plot_dict[">1 Mass Abnormality"] += 1
    if count == 1:
        to_plot_dict["1 Mass Abnormality"] += 1

to_plot_series = pd.Series(to_plot_dict)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(7, 5))
to_plot_series.plot.bar(ax=ax, color="#d3d3d3", edgecolor="black")

# Add values
for i, v in enumerate(to_plot_series):
    ax.text(x=(i-0.06), y=(v + 10), s=str(v), color="black")

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.grid(b=True, which="major", axis="y", color="#d3d3d3", linestyle="-")
ax.grid(b=True, which="minor", axis="y", color="#e7e7e7", linestyle="dashed")
ax.set_ylabel("Count")
ax.set_xticklabels(labels=ax.get_xticklabels(), rotation=0, ha="center")
ax.yaxis.set_ticks(np.arange(0, 1750, 250))
# ax.yaxis.set_minor_locator(MultipleLocator(50))
ax.patch.set_alpha(0)
ax.set_axisbelow(True)

# plt.savefig("/Users/cleonwong/Google Drive/To-Share/mammogram_medium_article/Part1/more_than_one_abnormality_plot.png", dpi=300, transparent=True)

# %%
## Conjunto de Teste
test_all_df = pd.read_csv("/datasets/mamografia/CBIS-DDSM_organized/csv-description/mass_case_description_test_set.csv")
new_cols = [col.replace(" ", "_") for col in test_all_df.columns]
test_all_df.columns = new_cols
test_all_df["identifier"] = test_all_df.apply(lambda x: "_".join([x["patient_id"], x["left_or_right_breast"], x["image_view"]]), axis=1)
temp = test_all_df.loc[test_all_df["abnormality_type"] == "mass"]["identifier"].value_counts()

to_plot_dict = {"1 Mass Abnormality":0, ">1 Mass Abnormality":0}

for count in temp:
    if count > 1:
        to_plot_dict[">1 Mass Abnormality"] += 1
    if count == 1:
        to_plot_dict["1 Mass Abnormality"] += 1

to_plot_series = pd.Series(to_plot_dict)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(7, 5))
to_plot_series.plot.bar(ax=ax, color="#d3d3d3", edgecolor="black")

# Add values
for i, v in enumerate(to_plot_series):
    ax.text(x=(i-0.06), y=(v + 10), s=str(v), color="black")

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.grid(b=True, which="major", axis="y", color="#d3d3d3", linestyle="-")
ax.grid(b=True, which="minor", axis="y", color="#e7e7e7", linestyle="dashed")
ax.set_ylabel("Count")
ax.set_xticklabels(labels=ax.get_xticklabels(), rotation=0, ha="center")
ax.yaxis.set_ticks(np.arange(0, 1750, 250))
# ax.yaxis.set_minor_locator(MultipleLocator(50))
ax.patch.set_alpha(0)
ax.set_axisbelow(True)

# %%
P00207_dcm = pydicom.dcmread("/datasets/mamografia/CBIS-DDSM_organized/images/train/Mass-Training_P_00207_LEFT_MLO_FULL.dcm")
P00207_crop1_dcm = pydicom.dcmread("/datasets/mamografia/CBIS-DDSM_organized/images/train/Mass-Training_P_00207_LEFT_MLO_CROP_3.dcm")
P00207_crop2_dcm = pydicom.dcmread("/datasets/mamografia/CBIS-DDSM_organized/images/train/Mass-Training_P_00207_LEFT_MLO_CROP_2.dcm")
P00207_crop3_dcm = pydicom.dcmread("/datasets/mamografia/CBIS-DDSM_organized/images/train/Mass-Training_P_00207_LEFT_MLO_CROP_1.dcm")
P00207_mask1_dcm = pydicom.dcmread("/datasets/mamografia/CBIS-DDSM_organized/images/train/Mass-Training_P_00207_LEFT_MLO_MASK_1.dcm")
P00207_mask2_dcm = pydicom.dcmread("/datasets/mamografia/CBIS-DDSM_organized/images/train/Mass-Training_P_00207_LEFT_MLO_MASK_2.dcm")
P00207_mask3_dcm = pydicom.dcmread("/datasets/mamografia/CBIS-DDSM_organized/images/train/Mass-Training_P_00207_LEFT_MLO_MASK_3.dcm")

P00207_arr = P00207_dcm.pixel_array
P00207_crop1_arr = P00207_crop1_dcm.pixel_array
P00207_crop2_arr = P00207_crop2_dcm.pixel_array
P00207_crop3_arr = P00207_crop3_dcm.pixel_array
P00207_mask1_arr = P00207_mask1_dcm.pixel_array
P00207_mask2_arr = P00207_mask2_dcm.pixel_array
P00207_mask3_arr = P00207_mask3_dcm.pixel_array

fig, ax = plt.subplots(nrows=3, ncols=3, figsize=(10, 15))

ax[0][1].imshow(P00207_arr, cmap="gray")
ax[1][0].imshow(P00207_mask1_arr, cmap="gray")
ax[1][1].imshow(P00207_mask2_arr, cmap="gray")
ax[1][2].imshow(P00207_mask3_arr, cmap="gray")
ax[2][0].imshow(P00207_crop1_arr, cmap="gray")
ax[2][1].imshow(P00207_crop2_arr, cmap="gray")
ax[2][2].imshow(P00207_crop3_arr, cmap="gray")

ax[0][0].axis('off')
ax[0][2].axis('off')

ax[0][1].set_title("Full Mammogram Scan")
ax[1][0].set_title("ROI Mask 1")
ax[1][1].set_title("ROI Mask 2")
ax[1][2].set_title("ROI Mask 3")
ax[2][0].set_title("Cropped Image 1")
ax[2][1].set_title("Cropped Image 2")
ax[2][2].set_title("Cropped Image 3")

plt.tight_layout()
# plt.savefig("/Users/cleonwong/Google Drive/To-Share/mammogram_medium_article/Part1/more_than_one_abnorm_example_P00207.png", dpi=300, transparent=True)

# %% [markdown]
# ### Pathology

# %%
plot_df = mass_all_df.groupby(["abnormality_type"])["pathology"].value_counts().unstack()
#new_row = plot_df.loc["calcification"] + plot_df.loc["mass"]
# new_row = plot_df.loc["calcification"] + plot_df.loc["mass"]
# new_row.name = "Calc + Mass"
# plot_df = plot_df.append(new_row, ignore_index=False)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(7, 5))
plot_df.plot.bar(ax=ax)

# %% [markdown]
# ### Pathology and abnormality type

# %%
path_ab_dict = {
    # "benign-calc":0,
    "benign-mass":0,
    # "malignant-calc":0,
    "malignant-mass":0
}

for row in mass_all_df.itertuples():
    
    pathology = row.pathology
    ab_type = row.abnormality_type
    
    # if pathology=="BENIGN" and ab_type=="calcification":
    #     path_ab_dict["benign-calc"] += 1
    if pathology=="BENIGN" and ab_type=="mass":
        path_ab_dict["benign-mass"] += 1
    # elif pathology=="MALIGNANT" and ab_type=="calcification":
    #     path_ab_dict["malignant-calc"] += 1
    elif pathology=="MALIGNANT" and ab_type=="mass":
        path_ab_dict["malignant-mass"] += 1

# %%
path_ab_df = pd.DataFrame.from_dict(data=path_ab_dict, orient="index")
path_ab_df
# Out:
#                   0
# benign-mass     577
# malignant-mass  637

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 7))

# Plot bars one by one in order to set the colours.
path_ab_df.plot.bar(ax=ax, color="#d3d3d3", edgecolor="black")
    
ax.set_title("Distribution of pathology-abnormality_type.")
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.grid(b=True, which="major", axis="y", color="#d3d3d3", linestyle="-")
ax.grid(b=True, which="minor", axis="y", color="#e7e7e7", linestyle="dashed")
ax.set_ylabel("Count")
ax.set_xticklabels(labels=ax.get_xticklabels(), rotation=45, ha="right")
ax.yaxis.set_ticks(np.arange(0, 850, 100))
ax.yaxis.set_minor_locator(MultipleLocator(50))
ax.patch.set_alpha(0)
ax.set_axisbelow(True)

# %% [markdown]
# ### Density

# %%
plot_df = mass_all_df.groupby(["abnormality_type"])["breast_density"].value_counts().unstack()
# new_row = plot_df.loc["calcification"] + plot_df.loc["mass"]
# new_row.name = "Calc + Mass"
# plot_df = plot_df.append(new_row, ignore_index=False)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(7, 5))
plot_df.plot.bar(ax=ax)

# %%
all_df = mass_all_df
all_df[(all_df["breast_density"]==4) & (all_df["abnormality_type"]=="mass")].head(30)
# Out:
#     patient_id  breast_density left_or_right_breast image_view  \
# 32     P_00045               4                 LEFT         CC
# 33     P_00045               4                 LEFT        MLO
# 37     P_00054               4                RIGHT        MLO
# 54     P_00076               4                 LEFT         CC
# 55     P_00076               4                 LEFT        MLO
# 102    P_00120               4                 LEFT         CC
# 103    P_00120               4                 LEFT        MLO
# 110    P_00137               4                 LEFT         CC
# 111    P_00137               4                 LEFT        MLO
# 124    P_00169               4                RIGHT        MLO
# 125    P_00172               4                 LEFT         CC
# 126    P_00172               4                 LEFT        MLO
# 129    P_00175               4                RIGHT         CC
# 130    P_00175               4                RIGHT        MLO
# 133    P_00190               4                 LEFT        MLO
# 158    P_00226               4                 LEFT         CC
# 159    P_00226               4                 LEFT        MLO
# 237    P_00348               4                 LEFT         CC
# 238    P_00348               4                 LEFT        MLO
# 244    P_00361               4                RIGHT        MLO
# 263    P_00389               4                 LEFT        MLO
# 270    P_00406               4                RIGHT         CC
# 271    P_00406               4                RIGHT        MLO
# 278    P_00413               4                 LEFT         CC
# 279    P_00413               4                 LEFT        MLO
# 314    P_00437               4                 LEFT         CC
# 315    P_00437               4                 LEFT        MLO
# 322    P_00444               4                 LEFT         CC
# 323    P_00444               4                 LEFT        MLO
# 345    P_00488               4                 LEFT         CC
#
#      abnormality_id abnormality_type                          mass_shape  \
# 32                1             mass            FOCAL_ASYMMETRIC_DENSITY
# 33                1             mass            FOCAL_ASYMMETRIC_DENSITY
# 37                1             mass                                OVAL
# 54                1             mass                                OVAL
# 55                1             mass                                OVAL
# 102               1             mass                               ROUND
# 103               1             mass                               ROUND
# 110               1             mass                               ROUND
# 111               1             mass                               ROUND
# 124               1             mass                           IRREGULAR
# 125               1             mass                           IRREGULAR
# 126               1             mass                           IRREGULAR
# 129               1             mass                           IRREGULAR
# 130               1             mass  IRREGULAR-ARCHITECTURAL_DISTORTION
# 133               1             mass                           IRREGULAR
# 158               1             mass            FOCAL_ASYMMETRIC_DENSITY
# 159               1             mass            FOCAL_ASYMMETRIC_DENSITY
# 237               1             mass                           IRREGULAR
# 238               1             mass                           IRREGULAR
# 244               1             mass                               ROUND
# 263               1             mass                               ROUND
# 270               1             mass                           IRREGULAR
# 271               1             mass                           IRREGULAR
# 278               1             mass  IRREGULAR-ARCHITECTURAL_DISTORTION
# 279               1             mass  IRREGULAR-ARCHITECTURAL_DISTORTION
# 314               1             mass                                OVAL
# 315               1             mass                                OVAL
# 322               1             mass                                OVAL
# 323               1             mass                                OVAL
# 345               1             mass                           IRREGULAR
#
#                mass_margins  assessment                pathology  subtlety  \
# 32              ILL_DEFINED           4                MALIGNANT         3
# 33              ILL_DEFINED           4                MALIGNANT         3
# 37            CIRCUMSCRIBED           3  BENIGN_WITHOUT_CALLBACK         4
# 54              ILL_DEFINED           4                   BENIGN         3
# 55              ILL_DEFINED           4                   BENIGN         3
# 102                OBSCURED           4                   BENIGN         5
# 103                OBSCURED           4                   BENIGN         5
# 110           CIRCUMSCRIBED           3                   BENIGN         3
# 111           CIRCUMSCRIBED           3                   BENIGN         3
# 124              SPICULATED           4  BENIGN_WITHOUT_CALLBACK         5
# 125              SPICULATED           5                MALIGNANT         5
# 126              SPICULATED           5                MALIGNANT         5
# 129                OBSCURED           4                MALIGNANT         3
# 130    OBSCURED-ILL_DEFINED           4                MALIGNANT         3
# 133              SPICULATED           5                MALIGNANT         5
# 158                     NaN           3                MALIGNANT         1
# 159                     NaN           3                MALIGNANT         1
# 237             ILL_DEFINED           4                   BENIGN         3
# 238             ILL_DEFINED           4                   BENIGN         3
# 244              SPICULATED           3                MALIGNANT         3
# 263                OBSCURED           4                   BENIGN         3
# 270              SPICULATED           5                MALIGNANT         4
# 271              SPICULATED           5                MALIGNANT         4
# 278  ILL_DEFINED-SPICULATED           4                MALIGNANT         4
# 279  ILL_DEFINED-SPICULATED           4                MALIGNANT         4
# 314                OBSCURED           3                   BENIGN         2
# 315                OBSCURED           3                   BENIGN         2
# 322              SPICULATED           4                MALIGNANT         3
# 323              SPICULATED           4                MALIGNANT         3
# 345  CIRCUMSCRIBED-OBSCURED           4                   BENIGN         3
#
#                                        image_file_path  \
# 32   Mass-Training_P_00045_LEFT_CC/1.3.6.1.4.1.9590...
# 33   Mass-Training_P_00045_LEFT_MLO/1.3.6.1.4.1.959...
# 37   Mass-Training_P_00054_RIGHT_MLO/1.3.6.1.4.1.95...
# 54   Mass-Training_P_00076_LEFT_CC/1.3.6.1.4.1.9590...
# 55   Mass-Training_P_00076_LEFT_MLO/1.3.6.1.4.1.959...
# 102  Mass-Training_P_00120_LEFT_CC/1.3.6.1.4.1.9590...
# 103  Mass-Training_P_00120_LEFT_MLO/1.3.6.1.4.1.959...
# 110  Mass-Training_P_00137_LEFT_CC/1.3.6.1.4.1.9590...
# 111  Mass-Training_P_00137_LEFT_MLO/1.3.6.1.4.1.959...
# 124  Mass-Training_P_00169_RIGHT_MLO/1.3.6.1.4.1.95...
# 125  Mass-Training_P_00172_LEFT_CC/1.3.6.1.4.1.9590...
# 126  Mass-Training_P_00172_LEFT_MLO/1.3.6.1.4.1.959...
# 129  Mass-Training_P_00175_RIGHT_CC/1.3.6.1.4.1.959...
# 130  Mass-Training_P_00175_RIGHT_MLO/1.3.6.1.4.1.95...
# 133  Mass-Training_P_00190_LEFT_MLO/1.3.6.1.4.1.959...
# 158  Mass-Training_P_00226_LEFT_CC/1.3.6.1.4.1.9590...
# 159  Mass-Training_P_00226_LEFT_MLO/1.3.6.1.4.1.959...
# 237  Mass-Training_P_00348_LEFT_CC/1.3.6.1.4.1.9590...
# 238  Mass-Training_P_00348_LEFT_MLO/1.3.6.1.4.1.959...
# 244  Mass-Training_P_00361_RIGHT_MLO/1.3.6.1.4.1.95...
# 263  Mass-Training_P_00389_LEFT_MLO/1.3.6.1.4.1.959...
# 270  Mass-Training_P_00406_RIGHT_CC/1.3.6.1.4.1.959...
# 271  Mass-Training_P_00406_RIGHT_MLO/1.3.6.1.4.1.95...
# 278  Mass-Training_P_00413_LEFT_CC/1.3.6.1.4.1.9590...
# 279  Mass-Training_P_00413_LEFT_MLO/1.3.6.1.4.1.959...
# 314  Mass-Training_P_00437_LEFT_CC/1.3.6.1.4.1.9590...
# 315  Mass-Training_P_00437_LEFT_MLO/1.3.6.1.4.1.959...
# 322  Mass-Training_P_00444_LEFT_CC/1.3.6.1.4.1.9590...
# 323  Mass-Training_P_00444_LEFT_MLO/1.3.6.1.4.1.959...
# 345  Mass-Training_P_00488_LEFT_CC/1.3.6.1.4.1.9590...
#
#                                cropped_image_file_path  \
# 32   Mass-Training_P_00045_LEFT_CC_1/1.3.6.1.4.1.95...
# 33   Mass-Training_P_00045_LEFT_MLO_1/1.3.6.1.4.1.9...
# 37   Mass-Training_P_00054_RIGHT_MLO_1/1.3.6.1.4.1....
# 54   Mass-Training_P_00076_LEFT_CC_1/1.3.6.1.4.1.95...
# 55   Mass-Training_P_00076_LEFT_MLO_1/1.3.6.1.4.1.9...
# 102  Mass-Training_P_00120_LEFT_CC_1/1.3.6.1.4.1.95...
# 103  Mass-Training_P_00120_LEFT_MLO_1/1.3.6.1.4.1.9...
# 110  Mass-Training_P_00137_LEFT_CC_1/1.3.6.1.4.1.95...
# 111  Mass-Training_P_00137_LEFT_MLO_1/1.3.6.1.4.1.9...
# 124  Mass-Training_P_00169_RIGHT_MLO_1/1.3.6.1.4.1....
# 125  Mass-Training_P_00172_LEFT_CC_1/1.3.6.1.4.1.95...
# 126  Mass-Training_P_00172_LEFT_MLO_1/1.3.6.1.4.1.9...
# 129  Mass-Training_P_00175_RIGHT_CC_1/1.3.6.1.4.1.9...
# 130  Mass-Training_P_00175_RIGHT_MLO_1/1.3.6.1.4.1....
# 133  Mass-Training_P_00190_LEFT_MLO_1/1.3.6.1.4.1.9...
# 158  Mass-Training_P_00226_LEFT_CC_1/1.3.6.1.4.1.95...
# 159  Mass-Training_P_00226_LEFT_MLO_1/1.3.6.1.4.1.9...
# 237  Mass-Training_P_00348_LEFT_CC_1/1.3.6.1.4.1.95...
# 238  Mass-Training_P_00348_LEFT_MLO_1/1.3.6.1.4.1.9...
# 244  Mass-Training_P_00361_RIGHT_MLO_1/1.3.6.1.4.1....
# 263  Mass-Training_P_00389_LEFT_MLO_1/1.3.6.1.4.1.9...
# 270  Mass-Training_P_00406_RIGHT_CC_1/1.3.6.1.4.1.9...
# 271  Mass-Training_P_00406_RIGHT_MLO_1/1.3.6.1.4.1....
# 278  Mass-Training_P_00413_LEFT_CC_1/1.3.6.1.4.1.95...
# 279  Mass-Training_P_00413_LEFT_MLO_1/1.3.6.1.4.1.9...
# 314  Mass-Training_P_00437_LEFT_CC_1/1.3.6.1.4.1.95...
# 315  Mass-Training_P_00437_LEFT_MLO_1/1.3.6.1.4.1.9...
# 322  Mass-Training_P_00444_LEFT_CC_1/1.3.6.1.4.1.95...
# 323  Mass-Training_P_00444_LEFT_MLO_1/1.3.6.1.4.1.9...
# 345  Mass-Training_P_00488_LEFT_CC_1/1.3.6.1.4.1.95...
#
#                                     ROI_mask_file_path         identifier
# 32   Mass-Training_P_00045_LEFT_CC_1/1.3.6.1.4.1.95...    P_00045_LEFT_CC
# 33   Mass-Training_P_00045_LEFT_MLO_1/1.3.6.1.4.1.9...   P_00045_LEFT_MLO
# 37   Mass-Training_P_00054_RIGHT_MLO_1/1.3.6.1.4.1....  P_00054_RIGHT_MLO
# 54   Mass-Training_P_00076_LEFT_CC_1/1.3.6.1.4.1.95...    P_00076_LEFT_CC
# 55   Mass-Training_P_00076_LEFT_MLO_1/1.3.6.1.4.1.9...   P_00076_LEFT_MLO
# 102  Mass-Training_P_00120_LEFT_CC_1/1.3.6.1.4.1.95...    P_00120_LEFT_CC
# 103  Mass-Training_P_00120_LEFT_MLO_1/1.3.6.1.4.1.9...   P_00120_LEFT_MLO
# 110  Mass-Training_P_00137_LEFT_CC_1/1.3.6.1.4.1.95...    P_00137_LEFT_CC
# 111  Mass-Training_P_00137_LEFT_MLO_1/1.3.6.1.4.1.9...   P_00137_LEFT_MLO
# 124  Mass-Training_P_00169_RIGHT_MLO_1/1.3.6.1.4.1....  P_00169_RIGHT_MLO
# 125  Mass-Training_P_00172_LEFT_CC_1/1.3.6.1.4.1.95...    P_00172_LEFT_CC
# 126  Mass-Training_P_00172_LEFT_MLO_1/1.3.6.1.4.1.9...   P_00172_LEFT_MLO
# 129  Mass-Training_P_00175_RIGHT_CC_1/1.3.6.1.4.1.9...   P_00175_RIGHT_CC
# 130  Mass-Training_P_00175_RIGHT_MLO_1/1.3.6.1.4.1....  P_00175_RIGHT_MLO
# 133  Mass-Training_P_00190_LEFT_MLO_1/1.3.6.1.4.1.9...   P_00190_LEFT_MLO
# 158  Mass-Training_P_00226_LEFT_CC_1/1.3.6.1.4.1.95...    P_00226_LEFT_CC
# 159  Mass-Training_P_00226_LEFT_MLO_1/1.3.6.1.4.1.9...   P_00226_LEFT_MLO
# 237  Mass-Training_P_00348_LEFT_CC_1/1.3.6.1.4.1.95...    P_00348_LEFT_CC
# 238  Mass-Training_P_00348_LEFT_MLO_1/1.3.6.1.4.1.9...   P_00348_LEFT_MLO
# 244  Mass-Training_P_00361_RIGHT_MLO_1/1.3.6.1.4.1....  P_00361_RIGHT_MLO
# 263  Mass-Training_P_00389_LEFT_MLO_1/1.3.6.1.4.1.9...   P_00389_LEFT_MLO
# 270  Mass-Training_P_00406_RIGHT_CC_1/1.3.6.1.4.1.9...   P_00406_RIGHT_CC
# 271  Mass-Training_P_00406_RIGHT_MLO_1/1.3.6.1.4.1....  P_00406_RIGHT_MLO
# 278  Mass-Training_P_00413_LEFT_CC_1/1.3.6.1.4.1.95...    P_00413_LEFT_CC
# 279  Mass-Training_P_00413_LEFT_MLO_1/1.3.6.1.4.1.9...   P_00413_LEFT_MLO
# 314  Mass-Training_P_00437_LEFT_CC_1/1.3.6.1.4.1.95...    P_00437_LEFT_CC
# 315  Mass-Training_P_00437_LEFT_MLO_1/1.3.6.1.4.1.9...   P_00437_LEFT_MLO
# 322  Mass-Training_P_00444_LEFT_CC_1/1.3.6.1.4.1.95...    P_00444_LEFT_CC
# 323  Mass-Training_P_00444_LEFT_MLO_1/1.3.6.1.4.1.9...   P_00444_LEFT_MLO
# 345  Mass-Training_P_00488_LEFT_CC_1/1.3.6.1.4.1.95...    P_00488_LEFT_CC

# %%
density_1 = [
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_00008_LEFT_CC_FULL.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_00048_RIGHT_MLO_FULL.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_00271_LEFT_CC_FULL.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Mass/Train_extracted/Mass-Training_P_00021_LEFT_CC_FULL.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Mass/Train_extracted/Mass-Training_P_00080_RIGHT_MLO_FULL.dcm"
]
density_1_ds = [pydicom.dcmread(path) for path in density_1]
density_1_arr = [_ds.pixel_array for _ds in density_1_ds]


density_2 = [
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Mass/Train_extracted/Mass-Training_P_00018_RIGHT_CC_FULL.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Mass/Train_extracted/Mass-Training_P_00051_LEFT_MLO_FULL.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Mass/Train_extracted/Mass-Training_P_00079_RIGHT_CC_FULL.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_00012_LEFT_CC_FULL.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_00159_LEFT_MLO_FULL.dcm"
]
density_2_ds = [pydicom.dcmread(path) for path in density_2]
density_2_arr = [_ds.pixel_array for _ds in density_2_ds]


density_3 = [
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_00005_RIGHT_CC_FULL.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_00084_LEFT_CC_FULL.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_00105_LEFT_CC_FULL.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Mass/Train_extracted/Mass-Training_P_00068_RIGHT_CC_FULL.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Mass/Train_extracted/Mass-Training_P_00134_LEFT_CC_FULL.dcm"
]
density_3_ds = [pydicom.dcmread(path) for path in density_3]
density_3_arr = [_ds.pixel_array for _ds in density_3_ds]


density_4 = [
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Mass/Train_extracted/Mass-Training_P_00045_LEFT_CC_FULL.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Mass/Train_extracted/Mass-Training_P_00172_LEFT_CC_FULL.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Mass/Train_extracted/Mass-Training_P_00444_LEFT_CC_FULL.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_00031_LEFT_CC_FULL.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_00181_RIGHT_MLO_FULL.dcm"
]
density_4_ds = [pydicom.dcmread(path) for path in density_4]
density_4_arr = [_ds.pixel_array for _ds in density_4_ds]

# %%
fig, ax = plt.subplots(nrows=4, ncols=5, figsize=(25, 20))

for i in range(5):
    ax[0][i].imshow(density_1_arr[i], cmap="gray")
    ax[1][i].imshow(density_2_arr[i], cmap="gray")
    ax[2][i].imshow(density_3_arr[i], cmap="gray")
    ax[3][i].imshow(density_4_arr[i], cmap="gray")
    
plt.tight_layout()

# %% [markdown]
# ### Density vs. pathology

# %%
calc_all_df["breast_density"].value_counts()
# Out:
# 3    654
# 2    616
# 4    401
# 1    199
# 0      2
# Name: breast_density, dtype: int64

# %%
mass_all_df["breast_density"].value_counts()
# Out:
# 2    585
# 3    337
# 1    287
# 4    109
# Name: breast_density, dtype: int64

# %%
# calc_plot = calc_all_df.groupby(["breast_density"])["pathology"].value_counts().unstack()
mass_plot = mass_all_df.groupby(["breast_density"])["pathology"].value_counts().unstack()

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(20, 6))
# calc_plot.plot.bar(ax=ax[0])
# mass_plot.plot.bar(ax=ax[1])
mass_plot.plot.bar(ax=ax)

# ax[0].set_title("Pathology counts vs. breast density (Calcification).")
# ax[0].spines['right'].set_visible(False)
# ax[0].spines['top'].set_visible(False)
# ax[0].spines['left'].set_visible(False)
# ax[0].grid(b=True, which="major", axis="both", color="#d3d3d3", linestyle="-")
# ax[0].grid(b=True, which="minor", axis="y", color="#e7e7e7", linestyle="dashed")
# ax[0].set_ylabel("Count")
# ax[0].yaxis.set_ticks(np.arange(0, 400, 50))
# ax[0].yaxis.set_minor_locator(MultipleLocator(25))
# ax[0].patch.set_alpha(0)
# ax[0].set_axisbelow(True)

ax.set_title("Pathology counts vs. breast density (Mass).")
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.grid(b=True, which="major", axis="both", color="#d3d3d3", linestyle="-")
ax.grid(b=True, which="minor", axis="y", color="#e7e7e7", linestyle="dashed")
ax.set_ylabel("Count")
ax.yaxis.set_ticks(np.arange(0, 400, 50))
ax.yaxis.set_minor_locator(MultipleLocator(25))
ax.patch.set_alpha(0)
ax.set_axisbelow(True)

plt.tight_layout()

# %% [markdown]
# ### Mass vs pathology

# %% [markdown]
# ### Mass shapes

# %%
mass_shapes = [shape for shape in mass_all_df["mass_shape"].unique() if str(shape) != "nan"]
mass_shapes
# Out:
# ['IRREGULAR-ARCHITECTURAL_DISTORTION',
#  'ARCHITECTURAL_DISTORTION',
#  'OVAL',
#  'IRREGULAR',
#  'LYMPH_NODE',
#  'LOBULATED-LYMPH_NODE',
#  'LOBULATED',
#  'FOCAL_ASYMMETRIC_DENSITY',
#  'ROUND',
#  'LOBULATED-ARCHITECTURAL_DISTORTION',
#  'ASYMMETRIC_BREAST_TISSUE',
#  'LOBULATED-IRREGULAR',
#  'OVAL-LYMPH_NODE',
#  'LOBULATED-OVAL',
#  'ROUND-OVAL',
#  'IRREGULAR-FOCAL_ASYMMETRIC_DENSITY',
#  'ROUND-IRREGULAR-ARCHITECTURAL_DISTORTION',
#  'ROUND-LOBULATED']

# %%
mass_all_df["mass_shape"].isnull().sum()
# Out:
# 4

# %%
mass_shape_singlelabel = [shape for shape in mass_shapes if "-" not in shape]
mass_shape_singlelabel
# Out:
# ['ARCHITECTURAL_DISTORTION',
#  'OVAL',
#  'IRREGULAR',
#  'LYMPH_NODE',
#  'LOBULATED',
#  'FOCAL_ASYMMETRIC_DENSITY',
#  'ROUND',
#  'ASYMMETRIC_BREAST_TISSUE']

# %%
plot_df = mass_all_df["mass_shape"].value_counts().to_frame()

# Create colour dictionary
color_dict = dict((shape, "#d3d3d3") for shape in mass_shapes)
for k, v in color_dict.items():
    if k in mass_shape_singlelabel:
        color_dict[k] = "#9696fd"

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 7))

# Plot bars one by one in order to set the colours.
for row in plot_df.itertuples():
    ax.bar(x=row.Index, height=row.mass_shape, color=color_dict[row.Index], edgecolor="black")

# Plot values
for i, v in enumerate(plot_df["mass_shape"]):
    ax.text(x=(i-0.25), y=(v + 10), s=str(v), color="black")
    
ax.set_title("Distribution of mass shapes.")
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.grid(b=True, which="major", axis="y", color="#d3d3d3", linestyle="-")
ax.grid(b=True, which="minor", axis="y", color="#e7e7e7", linestyle="dashed")
ax.set_ylabel("Count (mass shape)")
ax.set_xticklabels(labels=plot_df.index, rotation=45, ha="right")
ax.yaxis.set_ticks(np.arange(0, 550, 100))
ax.yaxis.set_minor_locator(MultipleLocator(50))
ax.patch.set_alpha(0)
ax.set_axisbelow(True)

# Add legend
colors = {"single label": "#9696fd", "multi-label":"#d3d3d3"}         
labels = list(colors.keys())
handles = [plt.Rectangle((0,0),1,1, color=colors[label]) for label in labels]
ax.legend(handles, labels)

# Get axis for next plot
x_labels = list(plot_df.index)

# %%
plot_df = mass_all_df.groupby(["mass_shape"])["pathology"].value_counts().unstack()
plot_df.drop(columns=["BENIGN_WITHOUT_CALLBACK"], inplace=True)
plot_df = plot_df.reindex(x_labels)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(20, 9))
plot_df.plot.bar(ax=ax)

ax.set_title("Mass shapes and pathology.")
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.grid(b=True, which="major", axis="y", color="#d3d3d3", linestyle="-")
ax.grid(b=True, which="minor", axis="y", color="#e7e7e7", linestyle="dashed")
ax.set_ylabel("Count (pathology per mass shape)")
ax.set_xticklabels(labels=plot_df.index, rotation=45, ha="right")
ax.yaxis.set_ticks(np.arange(0, 450, 100))
ax.yaxis.set_minor_locator(MultipleLocator(50))
ax.patch.set_alpha(0)
ax.set_axisbelow(True)

# %% [markdown]
# ### Calc type

# %%
calc_types = [calc for calc in calc_all_df["calc_type"].unique() if str(calc) != "nan"]
calc_types
# Out:
# ['AMORPHOUS',
#  'PLEOMORPHIC',
#  'ROUND_AND_REGULAR-LUCENT_CENTER-DYSTROPHIC',
#  'PUNCTATE',
#  'COARSE',
#  'VASCULAR',
#  'FINE_LINEAR_BRANCHING',
#  'LARGE_RODLIKE',
#  'PUNCTATE-LUCENT_CENTER',
#  'VASCULAR-COARSE-LUCENT_CENTER-ROUND_AND_REGULAR-PUNCTATE',
#  'ROUND_AND_REGULAR-EGGSHELL',
#  'PUNCTATE-PLEOMORPHIC',
#  'PLEOMORPHIC-FINE_LINEAR_BRANCHING',
#  'DYSTROPHIC',
#  'LUCENT_CENTER',
#  'AMORPHOUS-PLEOMORPHIC',
#  'ROUND_AND_REGULAR',
#  'VASCULAR-COARSE-LUCENT_CENTERED',
#  'COARSE-ROUND_AND_REGULAR',
#  'COARSE-PLEOMORPHIC',
#  'LUCENT_CENTERED',
#  'VASCULAR-COARSE',
#  'ROUND_AND_REGULAR-PUNCTATE',
#  'ROUND_AND_REGULAR-LUCENT_CENTER',
#  'COARSE-ROUND_AND_REGULAR-LUCENT_CENTERED',
#  'SKIN',
#  'LUCENT_CENTER-PUNCTATE',
#  'SKIN-PUNCTATE',
#  'SKIN-PUNCTATE-ROUND_AND_REGULAR',
#  'MILK_OF_CALCIUM',
#  'PLEOMORPHIC-PLEOMORPHIC',
#  'SKIN-COARSE-ROUND_AND_REGULAR',
#  'AMORPHOUS-ROUND_AND_REGULAR',
#  'ROUND_AND_REGULAR-PLEOMORPHIC',
#  'ROUND_AND_REGULAR-PUNCTATE-AMORPHOUS',
#  'ROUND_AND_REGULAR-AMORPHOUS',
#  'COARSE-ROUND_AND_REGULAR-LUCENT_CENTER',
#  'LARGE_RODLIKE-ROUND_AND_REGULAR',
#  'ROUND_AND_REGULAR-LUCENT_CENTER-PUNCTATE',
#  'COARSE-LUCENT_CENTER',
#  'PUNCTATE-AMORPHOUS',
#  'ROUND_AND_REGULAR-LUCENT_CENTERED',
#  'PUNCTATE-ROUND_AND_REGULAR',
#  'EGGSHELL',
#  'PUNCTATE-FINE_LINEAR_BRANCHING',
#  'PLEOMORPHIC-AMORPHOUS',
#  'PUNCTATE-AMORPHOUS-PLEOMORPHIC']

# %%
calc_all_df["calc_type"].isnull().sum()
# Out:
# 24

# %%
calc_type_singlelabel = [calc for calc in calc_types if "-" not in calc]
calc_type_singlelabel
# Out:
# ['AMORPHOUS',
#  'PLEOMORPHIC',
#  'PUNCTATE',
#  'COARSE',
#  'VASCULAR',
#  'FINE_LINEAR_BRANCHING',
#  'LARGE_RODLIKE',
#  'DYSTROPHIC',
#  'LUCENT_CENTER',
#  'ROUND_AND_REGULAR',
#  'LUCENT_CENTERED',
#  'SKIN',
#  'MILK_OF_CALCIUM',
#  'EGGSHELL']

# %%
plot_df = calc_all_df["calc_type"].value_counts().to_frame()


# Create colour dictionary
color_dict = dict((calc, "#d3d3d3") for calc in calc_types)
for k, v in color_dict.items():
    if k in calc_type_singlelabel:
        color_dict[k] = "#9696fd"

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 7))

# Plot bars one by one in order to set the colours.
for row in plot_df.itertuples():
    ax.bar(x=row.Index, height=row.calc_type, color=color_dict[row.Index], edgecolor="black")

# Plot values
for i, v in enumerate(plot_df["calc_type"]):
    ax.text(x=(i-0.25), y=(v + 10), s=str(v), color="black")
    
ax.set_title("Distribution of calc types.")
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.grid(b=True, which="major", axis="y", color="#d3d3d3", linestyle="-")
ax.grid(b=True, which="minor", axis="y", color="#e7e7e7", linestyle="dashed")
ax.set_ylabel("Count (calc type)")
ax.set_xticklabels(labels=plot_df.index, rotation=90, ha="center")
ax.yaxis.set_ticks(np.arange(0, 850, 100))
ax.yaxis.set_minor_locator(MultipleLocator(50))
ax.patch.set_alpha(0)
ax.set_axisbelow(True)

# Add legend
colors = {"single label": "#9696fd", "multi-label":"#d3d3d3"}         
labels = list(colors.keys())
handles = [plt.Rectangle((0,0),1,1, color=colors[label]) for label in labels]
ax.legend(handles, labels)
# Out:
# <ipython-input-246-afd101d1ad3a>:27: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels=plot_df.index, rotation=90, ha="center")

# %% [markdown]
# ### Calc distribution

# %%
calc_dists = [dist for dist in calc_all_df["calc_distribution"].unique() if str(dist) != "nan"]
calc_dists
# Out:
# ['CLUSTERED',
#  'LINEAR',
#  'REGIONAL',
#  'DIFFUSELY_SCATTERED',
#  'SEGMENTAL',
#  'CLUSTERED-LINEAR',
#  'CLUSTERED-SEGMENTAL',
#  'LINEAR-SEGMENTAL',
#  'REGIONAL-REGIONAL']

# %%
calc_all_df["calc_distribution"].isnull().sum()
# Out:
# 439

# %%
calc_dist_singlelabel = [dist for dist in calc_dists if "-" not in dist]
calc_dist_singlelabel
# Out:
# ['CLUSTERED', 'LINEAR', 'REGIONAL', 'DIFFUSELY_SCATTERED', 'SEGMENTAL']

# %%
plot_df = calc_all_df["calc_distribution"].value_counts().to_frame()
plot_df.loc["nan"] = calc_all_df["calc_distribution"].isnull().sum()
plot_df.sort_values(by=["calc_distribution"], ascending=False, inplace=True)

# Create colour dictionary
color_dict = dict((dist, "#d3d3d3") for dist in calc_dists)
color_dict["nan"] = "red"
for k, v in color_dict.items():
    if k in calc_dist_singlelabel:
        color_dict[k] = "#9696fd"
        

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 7))

# Plot bars one by one in order to set the colours.
for row in plot_df.itertuples():
    ax.bar(x=row.Index, height=row.calc_distribution, color=color_dict[row.Index], edgecolor="black")

# Plot values
for i, v in enumerate(plot_df["calc_distribution"]):
    ax.text(x=(i-0.1), y=(v + 10), s=str(v), color="black")
    
ax.set_title("Distribution of calc distribution.")
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.grid(b=True, which="major", axis="y", color="#d3d3d3", linestyle="-")
ax.grid(b=True, which="minor", axis="y", color="#e7e7e7", linestyle="dashed")
ax.set_ylabel("Count (calc distribution)")
ax.set_xticklabels(labels=plot_df.index, rotation=90, ha="center")
ax.yaxis.set_ticks(np.arange(0, 950, 100))
ax.yaxis.set_minor_locator(MultipleLocator(50))
ax.patch.set_alpha(0)
ax.set_axisbelow(True)

# Add legend
colors = {"single label": "#9696fd", "multi-label":"#d3d3d3", "nan": "red"}         
labels = list(colors.keys())
handles = [plt.Rectangle((0,0),1,1, color=colors[label]) for label in labels]
ax.legend(handles, labels)
# Out:
# <ipython-input-257-585e7d26d8ff>:30: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels=plot_df.index, rotation=90, ha="center")

# %% [markdown]
# ### Visualising P_00034 calc and mass

# %%
calc_path_00034 = [
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_00034_RIGHT_CC_FULL.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_00034_RIGHT_CC_CROP_2.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_00034_RIGHT_CC_MASK_2.dcm"
]

mass_path_00034 = [
"/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Mass/Train_extracted/Mass-Training_P_00034_RIGHT_CC_FULL.dcm",
"/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Mass/Train_extracted/Mass-Training_P_00034_RIGHT_CC_CROP_1.dcm",
"/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Mass/Train_extracted/Mass-Training_P_00027_RIGHT_MLO_MASK_1.dcm"

    
]

calc_ds = [pydicom.dcmread(calc_path_00034[i]) for i in range(len(calc_path_00034))]
mass_ds = [pydicom.dcmread(mass_path_00034[i]) for i in range(len(mass_path_00034))]

calc_arr = [_ds.pixel_array for _ds in calc_ds]
mass_arr = [_ds.pixel_array for _ds in mass_ds]

# %%
# Plot together
fig, ax = plt.sulots(nrows=2, ncols=3, figsize = (22, 14))

for i in range(3):
    ax[0][i].imshow(calc_arr[i], cmap="gray")
    ax[0][i].set_title(f"{calc_ds[i].PatientID}")
    
    ax[1][i].imshow(mass_arr[i], cmap="gray")
    ax[1][i].set_title(f"{mass_ds[i].PatientID}")
    
plt.tight_layout()

# %% [markdown]
# ### Visualising identifiers with more than 1 calc
# #### P_00112_RIGHT_MLO

# %%
calc_all_df["identifier"].value_counts()
# Out:
# P_00112_RIGHT_MLO    7
# P_01838_LEFT_MLO     7
# P_01099_LEFT_CC      6
# P_01408_LEFT_CC      6
# P_01437_LEFT_MLO     6
#                     ..
# P_00753_LEFT_CC      1
# P_00534_RIGHT_MLO    1
# P_02475_LEFT_MLO     1
# P_01700_RIGHT_CC     1
# P_01037_LEFT_CC      1
# Name: identifier, Length: 1511, dtype: int64

# %%
calc_path_full_00112 =     "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_00112_RIGHT_MLO_FULL.dcm"

calc_path_crop_00112 = [
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_00112_RIGHT_MLO_CROP_1.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_00112_RIGHT_MLO_CROP_2.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_00112_RIGHT_MLO_CROP_3.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_00112_RIGHT_MLO_CROP_4.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_00112_RIGHT_MLO_CROP_5.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_00112_RIGHT_MLO_CROP_6.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_00112_RIGHT_MLO_CROP_7.dcm"
]

calc_path_mask_00112 = [
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_00112_RIGHT_MLO_MASK_1.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_00112_RIGHT_MLO_MASK_2.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_00112_RIGHT_MLO_MASK_3.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_00112_RIGHT_MLO_MASK_4.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_00112_RIGHT_MLO_MASK_5.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_00112_RIGHT_MLO_MASK_6.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_00112_RIGHT_MLO_MASK_7.dcm"
]

# %%
calc_crop_ds = [pydicom.dcmread(calc_path_crop_00112[i]) for i in range(len(calc_path_crop_00112))]
calc_mask_ds = [pydicom.dcmread(calc_path_mask_00112[i]) for i in range(len(calc_path_mask_00112))]
calc_full_ds = pydicom.dcmread(calc_path_full_00112)

calc_crop_arr = [_ds.pixel_array for _ds in calc_crop_ds]
calc_mask_arr = [_ds.pixel_array for _ds in calc_mask_ds]
calc_full_arr = calc_full_ds.pixel_array

# %%
# Plot full
fig, ax = plt.subplots(nrows=1, ncols=1, figsize = (5, 5))

ax.imshow(calc_full_arr, cmap="gray")

plt.tight_layout()

# %%
# Plot together
fig, ax = plt.subplots(nrows=2, ncols=7, figsize = (20, 7))


for i in range(len(calc_crop_ds)):
    ax[0][i].imshow(calc_crop_arr[i], cmap="gray")
    ax[1][i].imshow(calc_mask_arr[i], cmap="gray")

plt.tight_layout()

# %% [markdown]
# #### P_01838_LEFT_MLO

# %%
calc_path_full_01838 = "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_01838_LEFT_MLO_FULL.dcm"

calc_path_crop_01838 = [
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_01838_LEFT_MLO_CROP_1.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_01838_LEFT_MLO_CROP_2.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_01838_LEFT_MLO_CROP_3.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_01838_LEFT_MLO_CROP_4.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_01838_LEFT_MLO_CROP_5.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_01838_LEFT_MLO_CROP_6.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_01838_LEFT_MLO_CROP_7.dcm"
]

calc_path_mask_01838 = [
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_01838_LEFT_MLO_MASK_1.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_01838_LEFT_MLO_MASK_2.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_01838_LEFT_MLO_MASK_3.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_01838_LEFT_MLO_MASK_4.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_01838_LEFT_MLO_MASK_5.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_01838_LEFT_MLO_MASK_6.dcm",
    "/Users/cleonwong/Dropbox (Holmusk)/mammogram-cv/CBIS-DDSM/Calc/Train/Calc-Training_P_01838_LEFT_MLO_MASK_7.dcm"
]

# %%
calc_crop_ds = [pydicom.dcmread(calc_path_crop_01838[i]) for i in range(len(calc_path_crop_01838))]
calc_mask_ds = [pydicom.dcmread(calc_path_mask_01838[i]) for i in range(len(calc_path_mask_01838))]
calc_full_ds = pydicom.dcmread(calc_path_full_01838)

calc_crop_arr = [_ds.pixel_array for _ds in calc_crop_ds]
calc_mask_arr = [_ds.pixel_array for _ds in calc_mask_ds]
calc_full_arr = calc_full_ds.pixel_array

# %%
# Plot full
fig, ax = plt.subplots(nrows=1, ncols=1, figsize = (5, 5))

ax.imshow(calc_full_arr, cmap="gray")

plt.tight_layout()

# %%
# Plot together
fig, ax = plt.subplots(nrows=2, ncols=7, figsize = (20, 7))


for i in range(len(calc_crop_ds)):
    ax[0][i].imshow(calc_crop_arr[i], cmap="gray")
    ax[1][i].imshow(calc_mask_arr[i], cmap="gray")

plt.tight_layout()
